# %%
# !pip install lightgbm openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightgbm in c:\users\administrator\appdata\roaming\python\python311\site-packages (4.4.0)
# Requirement already satisfied: openpyxl in e:\anaconda\lib\site-packages (3.0.10)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in e:\anaconda\lib\site-packages (from lightgbm) (1.11.1)
# Requirement already satisfied: et_xmlfile in e:\anaconda\lib\site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, KFold, GroupKFold
from sklearn.metrics import f1_score
from rdkit import Chem
from rdkit.Chem import Descriptors
from sklearn.feature_extraction.text import TfidfVectorizer
import tqdm, sys, os, gc, re, argparse, warnings
from lightgbm import log_evaluation, early_stopping
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import re

train = pd.read_excel('./dataset-new/traindata-new.xlsx')
test = pd.read_excel('./dataset-new/testdata-new.xlsx')

# test数据不包含 DC50 (nM) 和 Dmax (%)
train = train.drop(['DC50 (nM)', 'Dmax (%)'], axis=1)

# 定义了一个空列表drop_cols，用于存储在测试数据集中非空值小于10个的列名。
drop_cols = []
for f in test.columns:
    if test[f].notnull().sum() < 10:
        drop_cols.append(f)
        
# 使用drop方法从训练集和测试集中删除了这些列，以避免在后续的分析或建模中使用这些包含大量缺失值的列
train = train.drop(drop_cols, axis=1)
test = test.drop(drop_cols, axis=1)

# 使用pd.concat将清洗后的训练集和测试集合并成一个名为data的DataFrame，便于进行统一的特征工程处理
data = pd.concat([train, test], axis=0, ignore_index=True)
cols = data.columns[2:]

# 将SMILES转换为分子对象列表,并转换为SMILES字符串列表
data['smiles_list'] = data['Smiles'].apply(lambda x:[Chem.MolToSmiles(mol, isomericSmiles=True) for mol in [Chem.MolFromSmiles(x)]])
data['smiles_list'] = data['smiles_list'].map(lambda x: ' '.join(x))  

# 使用TfidfVectorizer计算TF-IDF
tfidf = TfidfVectorizer(max_df = 0.9, min_df = 1, sublinear_tf = True)
res = tfidf.fit_transform(data['smiles_list'])

# 将结果转为dataframe格式
tfidf_df = pd.DataFrame(res.toarray())
tfidf_df.columns = [f'smiles_tfidf_{i}' for i in range(tfidf_df.shape[1])]

# 按列合并到data数据
data = pd.concat([data, tfidf_df], axis=1)

# 自然数编码
def label_encode(series):
    unique = list(series.unique())
    return series.map(dict(zip(
        unique, range(series.nunique())
    )))

for col in cols:
    if data[col].dtype == 'object':
        data[col]  = label_encode(data[col])
        
train = data[data.Label.notnull()].reset_index(drop=True)
test = data[data.Label.isnull()].reset_index(drop=True)

# 特征筛选
features = [f for f in train.columns if f not in ['uuid','Label','smiles_list']]

# 构建训练集和测试集
x_train = train[features]
x_test = test[features]

# 训练集标签
y_train = train['Label'].astype(int)



atomic_masses = {
    'H': 1.008, 'He': 4.002602, 'Li': 6.94, 'Be': 9.0122, 'B': 10.81, 'C': 12.01,
    'N': 14.01, 'O': 16.00, 'F': 19.00, 'Ne': 20.180, 'Na': 22.990, 'Mg': 24.305,
    'Al': 26.982, 'Si': 28.085, 'P': 30.97, 'S': 32.07, 'Cl': 35.45, 'Ar': 39.95,
    'K': 39.10, 'Ca': 40.08, 'Sc': 44.956, 'Ti': 47.867, 'V': 50.942, 'Cr': 52.00,
    'Mn': 54.938, 'Fe': 55.845, 'Co': 58.933, 'Ni': 58.69, 'Cu': 63.55, 'Zn': 65.38
}

def parse_inchi(row):
    inchi_str = row['InChI']
    if not isinstance(inchi_str, str):
        inchi_str = str(inchi_str)
    formula = ''
    molecular_weight = 0
    element_counts = {}

    formula_match = re.search(r"InChI=1S/([^/]+)/c", inchi_str)
    if formula_match:
        formula = formula_match.group(1)

    for element, count in re.findall(r"([A-Z][a-z]*)([0-9]*)", formula):
        count = int(count) if count else 1
        element_mass = atomic_masses.get(element.upper(), 0)
        molecular_weight += element_mass * count
        element_counts[element.upper()] = count

    return pd.Series({
        'Formula': formula,
        'MolecularWeight': molecular_weight,
        'ElementCounts': element_counts
    })

train[['Formula', 'MolecularWeight', 'ElementCounts']] = train.apply(parse_inchi, axis=1)

# 定义存在的key
keys = ['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn']

# 创建一个空的DataFrame，列名为keys
df_expanded = pd.DataFrame({key: pd.Series() for key in keys})

# 遍历数据，填充DataFrame
for index, item in enumerate(train['ElementCounts'].values):
    for key in keys:
        # 将字典中的值填充到相应的列中
        df_expanded.at[index, key] = item.get(key, 0)
        
df_expanded = pd.DataFrame(df_expanded)

# %%
def clean_feature_names(df):
    df.columns = [re.sub('[^A-Za-z0-9_]+', '', col) for col in df.columns]
    return df

def cv_model(clf, train_x, train_y, test_x, clf_name, seed=2023):
    folds = 5
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)
    oof = np.zeros(train_x.shape[0])
    test_predict = np.zeros(test_x.shape[0])
    cv_scores = []
    
    for i, (train_index, valid_index) in enumerate(kf.split(train_x, train_y)):
        print('************************************ {} ************************************'.format(str(i+1)))
        trn_x, trn_y, val_x, val_y = train_x.iloc[train_index], train_y[train_index], train_x.iloc[valid_index], train_y[valid_index]
        
        # 清理特征名，以防万一再清理验证集和测试集
        trn_x = clean_feature_names(trn_x.copy())
        val_x = clean_feature_names(val_x.copy())
        test_x = clean_feature_names(test_x.copy())
        
        try:
            if clf_name == "lgb":
                train_matrix = clf.Dataset(trn_x, label=trn_y)
                valid_matrix = clf.Dataset(val_x, label=val_y)
                params = {
                    'boosting_type': 'gbdt',
                    'objective': 'binary',
                    'min_child_weight': 6,
                    'num_leaves': 2 ** 6,
                    'lambda_l2': 10,
                    'feature_fraction': 0.8,
                    'bagging_fraction': 0.8,
                    'bagging_freq': 4,
                    'learning_rate': 0.35,
                    'seed': 2024,
                    'nthread' : 16,
                    'verbose' : -1,
                }
                model = clf.train(
                    params, 
                    train_matrix, 
                    2000, 
                    valid_sets=[train_matrix, valid_matrix],
                    categorical_feature=[], 
                    callbacks=[early_stopping(stopping_rounds=100), log_evaluation(period=1000)]
                )
                val_pred = model.predict(val_x, num_iteration=model.best_iteration)
                test_pred = model.predict(test_x, num_iteration=model.best_iteration)
            
            if clf_name == "xgb":
                xgb_params = {
                  'booster': 'gbtree', 
                  'objective': 'binary:logistic',
                  'max_depth': 5,
                  'lambda': 10,
                  'subsample': 0.7,
                  'colsample_bytree': 0.7,
                  'colsample_bylevel': 0.7,
                  'eta': 0.35,
                  'tree_method': 'hist',
                  'seed': 520,
                  'nthread': 16
                }
                train_matrix = xgb.DMatrix(trn_x, label=trn_y)
                valid_matrix = xgb.DMatrix(val_x, label=val_y)
                test_matrix = xgb.DMatrix(test_x)
                
                watchlist = [(train_matrix, 'train'), (valid_matrix, 'eval')]
                
                model = xgb.train(xgb_params, train_matrix, num_boost_round=2000, evals=watchlist, verbose_eval=1000, early_stopping_rounds=100)
                val_pred = model.predict(valid_matrix)
                test_pred = model.predict(test_matrix)
            
            if clf_name == "cat":
                params = {'learning_rate': 0.35, 'depth': 5, 'bootstrap_type': 'Bernoulli', 'random_seed': 2024,
                          'od_type': 'Iter', 'od_wait': 100, 'allow_writing_files': False}
                
                model = CatBoostClassifier(iterations=2000, **params)
                model.fit(trn_x, trn_y, eval_set=[(val_x, val_y)],
                          logging_level='Verbose',
                          use_best_model=True, 
                          cat_features=[])
                
                val_pred = model.predict_proba(val_x)[:, 1]
                test_pred = model.predict_proba(test_x)[:, 1]
            
            oof[valid_index] = val_pred
            test_predict += test_pred / kf.n_splits
            
            F1_score = f1_score(val_y, np.where(val_pred > 0.5, 1, 0))
            cv_scores.append(F1_score)
            print(cv_scores)
        
        except Exception as e:
            print(f"Error in fold {i+1}: {str(e)}")
        
    return oof, test_predict

# 示例数据
# 请确保 x_train, y_train, x_test 变量已经被正确定义并赋值
# x_train = ...
# y_train = ...
# x_test = ...
# test = ...

# 选择LightGBM模型
try:
    lgb_oof, lgb_test = cv_model(lgb, x_train, y_train, x_test, 'lgb')
except Exception as e:
    print(f"Error with LightGBM: {str(e)}")

# 选择XGBoost模型
try:
    xgb_oof, xgb_test = cv_model(xgb, x_train, y_train, x_test, 'xgb')
except Exception as e:
    print(f"Error with XGBoost: {str(e)}")

# 选择CatBoost模型
try:
    cat_oof, cat_test = cv_model(CatBoostClassifier, x_train, y_train, x_test, 'cat')
except Exception as e:
    print(f"Error with CatBoost: {str(e)}")

# 进行取平均融合
try:
    final_test = (lgb_test + xgb_test + cat_test) / 3
    # 保存结果文件到本地
    pd.DataFrame(
        {
            'uuid': test['uuid'],
            'Label': np.where(final_test > 0.5, 1, 0)  # 根据预测概率生成标签
        }
    ).to_csv('submit.csv', index=None)
except Exception as e:
    print(f"Error during final fusion and saving: {str(e)}")
# Out:
# ************************************ 1 ************************************
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	training's binary_logloss: 0.176065	valid_1's binary_logloss: 0.344137
# [0.9009009009009009]
# ************************************ 2 ************************************
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.247589	valid_1's binary_logloss: 0.429617
# [0.9009009009009009, 0.8421052631578947]
# ************************************ 3 ************************************
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [159]	training's binary_logloss: 0.176589	valid_1's binary_logloss: 0.290863
# [0.9009009009009009, 0.8421052631578947, 0.9302325581395349]
# ************************************ 4 ************************************
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [140]	training's binary_logloss: 0.175399	valid_1's binary_logloss: 0.363591
# [0.9009009009009009, 0.8421052631578947, 0.9302325581395349, 0.8378378378378379]
# ************************************ 5 ************************************
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [124]	training's binary_logloss: 0.184818	valid_1's binary_logloss: 0.267493
# [0.9009009009009009, 0.8421052631578947, 0.9302325581395349, 0.8378378378378379, 0.9361702127659574]
# ************************************ 1 ************************************
# [0]	train-logloss:0.56534	eval-logloss:0.53091
# [192]	train-logloss:0.05345	eval-logloss:0.32461
# [0.9285714285714285]
# ************************************ 2 ************************************
# [0]	train-logloss:0.55469	eval-logloss:0.59901
# [151]	train-logloss:0.06245	eval-logloss:0.38619
# [0.9285714285714285, 0.8571428571428572]
# ************************************ 3 ************************************
# [0]	train-logloss:0.56610	eval-logloss:0.58426
# [140]	train-logloss:0.07033	eval-logloss:0.30372
# [0.9285714285714285, 0.8571428571428572, 0.9195402298850575]
# ************************************ 4 ************************************
# [0]	train-logloss:0.54461	eval-logloss:0.67569
# [152]	train-logloss:0.06431	eval-logloss:0.36804
# [0.9285714285714285, 0.8571428571428572, 0.9195402298850575, 0.8648648648648648]
# ************************************ 5 ************************************
# [0]	train-logloss:0.56597	eval-logloss:0.54180
# [189]	train-logloss:0.05195	eval-logloss:0.26816
# [0.9285714285714285, 0.8571428571428572, 0.9195402298850575, 0.8648648648648648, 0.9263157894736843]
# ************************************ 1 ************************************
# 0:	learn: 0.5206031	test: 0.5432373	best: 0.5432373 (0)	total: 146ms	remaining: 4m 51s
# 1:	learn: 0.4356642	test: 0.4667812	best: 0.4667812 (1)	total: 148ms	remaining: 2m 27s
# 2:	learn: 0.3975278	test: 0.4358311	best: 0.4358311 (2)	total: 151ms	remaining: 1m 40s
# 3:	learn: 0.3464025	test: 0.4085647	best: 0.4085647 (3)	total: 153ms	remaining: 1m 16s
# 4:	learn: 0.3139241	test: 0.3944932	best: 0.3944932 (4)	total: 155ms	remaining: 1m 1s
# 5:	learn: 0.2836030	test: 0.3967285	best: 0.3944932 (4)	total: 157ms	remaining: 52s
# 6:	learn: 0.2774774	test: 0.3958385	best: 0.3944932 (4)	total: 158ms	remaining: 45.1s
# 7:	learn: 0.2597375	test: 0.3919394	best: 0.3919394 (7)	total: 161ms	remaining: 40s
# 8:	learn: 0.2365760	test: 0.3885148	best: 0.3885148 (8)	total: 162ms	remaining: 35.9s
# 9:	learn: 0.2208424	test: 0.3913093	best: 0.3885148 (8)	total: 164ms	remaining: 32.7s
# 10:	learn: 0.2103530	test: 0.4000195	best: 0.3885148 (8)	total: 166ms	remaining: 30s
# 11:	learn: 0.2039978	test: 0.3969805	best: 0.3885148 (8)	total: 168ms	remaining: 27.8s
# 12:	learn: 0.1987478	test: 0.3932884	best: 0.3885148 (8)	total: 169ms	remaining: 25.9s
# 13:	learn: 0.1942737	test: 0.3921112	best: 0.3885148 (8)	total: 171ms	remaining: 24.2s
# 14:	learn: 0.1895796	test: 0.3880595	best: 0.3880595 (14)	total: 172ms	remaining: 22.8s
# 15:	learn: 0.1856068	test: 0.3859189	best: 0.3859189 (15)	total: 174ms	remaining: 21.6s
# 16:	learn: 0.1770861	test: 0.3682064	best: 0.3682064 (16)	total: 175ms	remaining: 20.5s
# 17:	learn: 0.1727474	test: 0.3671677	best: 0.3671677 (17)	total: 177ms	remaining: 19.5s
# 18:	learn: 0.1690473	test: 0.3683963	best: 0.3671677 (17)	total: 179ms	remaining: 18.6s
# 19:	learn: 0.1647495	test: 0.3690695	best: 0.3671677 (17)	total: 180ms	remaining: 17.8s
# 20:	learn: 0.1616622	test: 0.3686194	best: 0.3671677 (17)	total: 182ms	remaining: 17.1s
# 21:	learn: 0.1582369	test: 0.3688215	best: 0.3671677 (17)	total: 183ms	remaining: 16.5s
# 22:	learn: 0.1536000	test: 0.3691299	best: 0.3671677 (17)	total: 185ms	remaining: 15.9s
# 23:	learn: 0.1486161	test: 0.3744265	best: 0.3671677 (17)	total: 186ms	remaining: 15.3s
# 24:	learn: 0.1463770	test: 0.3745004	best: 0.3671677 (17)	total: 188ms	remaining: 14.8s
# 25:	learn: 0.1432499	test: 0.3805133	best: 0.3671677 (17)	total: 189ms	remaining: 14.4s
# 26:	learn: 0.1365374	test: 0.3702884	best: 0.3671677 (17)	total: 191ms	remaining: 13.9s
# 27:	learn: 0.1342631	test: 0.3704552	best: 0.3671677 (17)	total: 193ms	remaining: 13.6s
# 28:	learn: 0.1317523	test: 0.3709138	best: 0.3671677 (17)	total: 194ms	remaining: 13.2s
# 29:	learn: 0.1228503	test: 0.3670623	best: 0.3670623 (29)	total: 196ms	remaining: 12.8s
# 30:	learn: 0.1130093	test: 0.3654013	best: 0.3654013 (30)	total: 197ms	remaining: 12.5s
# 31:	learn: 0.1117716	test: 0.3664822	best: 0.3654013 (30)	total: 199ms	remaining: 12.2s
# 32:	learn: 0.1105025	test: 0.3676583	best: 0.3654013 (30)	total: 201ms	remaining: 12s
# 33:	learn: 0.1095136	test: 0.3677650	best: 0.3654013 (30)	total: 202ms	remaining: 11.7s
# 34:	learn: 0.0966335	test: 0.3759527	best: 0.3654013 (30)	total: 204ms	remaining: 11.4s
# 35:	learn: 0.0949252	test: 0.3750267	best: 0.3654013 (30)	total: 206ms	remaining: 11.2s
# 36:	learn: 0.0935233	test: 0.3760197	best: 0.3654013 (30)	total: 207ms	remaining: 11s
# 37:	learn: 0.0926909	test: 0.3757326	best: 0.3654013 (30)	total: 209ms	remaining: 10.8s
# 38:	learn: 0.0908920	test: 0.3699874	best: 0.3654013 (30)	total: 210ms	remaining: 10.6s
# 39:	learn: 0.0880782	test: 0.3658514	best: 0.3654013 (30)	total: 212ms	remaining: 10.4s
# 40:	learn: 0.0871037	test: 0.3657980	best: 0.3654013 (30)	total: 213ms	remaining: 10.2s
# 41:	learn: 0.0861464	test: 0.3665996	best: 0.3654013 (30)	total: 215ms	remaining: 10s
# 42:	learn: 0.0804079	test: 0.3651596	best: 0.3651596 (42)	total: 217ms	remaining: 9.86s
# 43:	learn: 0.0797482	test: 0.3657416	best: 0.3651596 (42)	total: 218ms	remaining: 9.71s
# 44:	learn: 0.0757769	test: 0.3762364	best: 0.3651596 (42)	total: 220ms	remaining: 9.55s
# 45:	learn: 0.0745939	test: 0.3776377	best: 0.3651596 (42)	total: 221ms	remaining: 9.41s
# 46:	learn: 0.0738006	test: 0.3777581	best: 0.3651596 (42)	total: 223ms	remaining: 9.27s
# 47:	learn: 0.0731878	test: 0.3810052	best: 0.3651596 (42)	total: 225ms	remaining: 9.14s
# 48:	learn: 0.0729022	test: 0.3812029	best: 0.3651596 (42)	total: 226ms	remaining: 9.01s
# 49:	learn: 0.0724628	test: 0.3813398	best: 0.3651596 (42)	total: 228ms	remaining: 8.89s
# 50:	learn: 0.0721304	test: 0.3815768	best: 0.3651596 (42)	total: 229ms	remaining: 8.77s
# 51:	learn: 0.0694510	test: 0.3792999	best: 0.3651596 (42)	total: 231ms	remaining: 8.65s
# 52:	learn: 0.0693153	test: 0.3795118	best: 0.3651596 (42)	total: 233ms	remaining: 8.54s
# 53:	learn: 0.0689254	test: 0.3815572	best: 0.3651596 (42)	total: 234ms	remaining: 8.45s
# 54:	learn: 0.0685313	test: 0.3823372	best: 0.3651596 (42)	total: 236ms	remaining: 8.35s
# 55:	learn: 0.0680020	test: 0.3821789	best: 0.3651596 (42)	total: 238ms	remaining: 8.25s
# 56:	learn: 0.0676211	test: 0.3830266	best: 0.3651596 (42)	total: 239ms	remaining: 8.16s
# 57:	learn: 0.0650322	test: 0.3903734	best: 0.3651596 (42)	total: 241ms	remaining: 8.06s
# 58:	learn: 0.0646702	test: 0.3909416	best: 0.3651596 (42)	total: 243ms	remaining: 7.98s
# 59:	learn: 0.0613653	test: 0.3871728	best: 0.3651596 (42)	total: 244ms	remaining: 7.89s
# 60:	learn: 0.0608150	test: 0.3865359	best: 0.3651596 (42)	total: 246ms	remaining: 7.8s
# 61:	learn: 0.0604338	test: 0.3873788	best: 0.3651596 (42)	total: 247ms	remaining: 7.72s
# 62:	learn: 0.0600804	test: 0.3883740	best: 0.3651596 (42)	total: 249ms	remaining: 7.64s
# 63:	learn: 0.0597559	test: 0.3889029	best: 0.3651596 (42)	total: 250ms	remaining: 7.57s
# 64:	learn: 0.0578924	test: 0.3913114	best: 0.3651596 (42)	total: 252ms	remaining: 7.49s
# 65:	learn: 0.0576048	test: 0.3939449	best: 0.3651596 (42)	total: 253ms	remaining: 7.42s
# 66:	learn: 0.0574838	test: 0.3945691	best: 0.3651596 (42)	total: 255ms	remaining: 7.36s
# 67:	learn: 0.0572481	test: 0.3946472	best: 0.3651596 (42)	total: 257ms	remaining: 7.29s
# 68:	learn: 0.0569966	test: 0.3932551	best: 0.3651596 (42)	total: 258ms	remaining: 7.22s
# 69:	learn: 0.0568159	test: 0.3936740	best: 0.3651596 (42)	total: 260ms	remaining: 7.16s
# 70:	learn: 0.0563985	test: 0.3922227	best: 0.3651596 (42)	total: 261ms	remaining: 7.09s
# 71:	learn: 0.0559035	test: 0.3915119	best: 0.3651596 (42)	total: 262ms	remaining: 7.03s
# 72:	learn: 0.0556178	test: 0.3933265	best: 0.3651596 (42)	total: 264ms	remaining: 6.96s
# 73:	learn: 0.0551340	test: 0.3992236	best: 0.3651596 (42)	total: 265ms	remaining: 6.91s
# 74:	learn: 0.0549421	test: 0.3990499	best: 0.3651596 (42)	total: 267ms	remaining: 6.85s
# 75:	learn: 0.0547098	test: 0.4021147	best: 0.3651596 (42)	total: 269ms	remaining: 6.8s
# 76:	learn: 0.0544151	test: 0.4030836	best: 0.3651596 (42)	total: 270ms	remaining: 6.75s
# 77:	learn: 0.0542275	test: 0.4031194	best: 0.3651596 (42)	total: 272ms	remaining: 6.7s
# 78:	learn: 0.0541795	test: 0.4028865	best: 0.3651596 (42)	total: 273ms	remaining: 6.65s
# 79:	learn: 0.0541564	test: 0.4034576	best: 0.3651596 (42)	total: 275ms	remaining: 6.6s
# 80:	learn: 0.0540610	test: 0.4038099	best: 0.3651596 (42)	total: 276ms	remaining: 6.55s
# 81:	learn: 0.0538506	test: 0.4038694	best: 0.3651596 (42)	total: 278ms	remaining: 6.5s
# 82:	learn: 0.0536735	test: 0.4037289	best: 0.3651596 (42)	total: 279ms	remaining: 6.45s
# 83:	learn: 0.0535028	test: 0.4035853	best: 0.3651596 (42)	total: 280ms	remaining: 6.4s
# 84:	learn: 0.0529653	test: 0.4055791	best: 0.3651596 (42)	total: 282ms	remaining: 6.35s
# 85:	learn: 0.0511381	test: 0.4087943	best: 0.3651596 (42)	total: 283ms	remaining: 6.31s
# 86:	learn: 0.0508204	test: 0.4096264	best: 0.3651596 (42)	total: 285ms	remaining: 6.27s
# 87:	learn: 0.0506159	test: 0.4090571	best: 0.3651596 (42)	total: 287ms	remaining: 6.23s
# 88:	learn: 0.0504899	test: 0.4091490	best: 0.3651596 (42)	total: 288ms	remaining: 6.19s
# 89:	learn: 0.0503831	test: 0.4078950	best: 0.3651596 (42)	total: 290ms	remaining: 6.15s
# 90:	learn: 0.0502207	test: 0.4095326	best: 0.3651596 (42)	total: 291ms	remaining: 6.11s
# 91:	learn: 0.0500303	test: 0.4095224	best: 0.3651596 (42)	total: 293ms	remaining: 6.07s
# 92:	learn: 0.0498592	test: 0.4097699	best: 0.3651596 (42)	total: 294ms	remaining: 6.03s
# 93:	learn: 0.0496770	test: 0.4104832	best: 0.3651596 (42)	total: 296ms	remaining: 5.99s
# 94:	learn: 0.0492992	test: 0.4096613	best: 0.3651596 (42)	total: 297ms	remaining: 5.95s
# 95:	learn: 0.0489352	test: 0.4108555	best: 0.3651596 (42)	total: 298ms	remaining: 5.92s
# 96:	learn: 0.0487945	test: 0.4099696	best: 0.3651596 (42)	total: 300ms	remaining: 5.88s
# 97:	learn: 0.0487945	test: 0.4099671	best: 0.3651596 (42)	total: 301ms	remaining: 5.85s
# 98:	learn: 0.0487016	test: 0.4099991	best: 0.3651596 (42)	total: 303ms	remaining: 5.82s
# 99:	learn: 0.0486165	test: 0.4102891	best: 0.3651596 (42)	total: 305ms	remaining: 5.79s
# 100:	learn: 0.0484864	test: 0.4109294	best: 0.3651596 (42)	total: 306ms	remaining: 5.76s
# 101:	learn: 0.0484371	test: 0.4091189	best: 0.3651596 (42)	total: 308ms	remaining: 5.72s
# 102:	learn: 0.0483333	test: 0.4113846	best: 0.3651596 (42)	total: 309ms	remaining: 5.69s
# 103:	learn: 0.0482559	test: 0.4117579	best: 0.3651596 (42)	total: 310ms	remaining: 5.66s
# 104:	learn: 0.0466408	test: 0.4141960	best: 0.3651596 (42)	total: 312ms	remaining: 5.63s
# 105:	learn: 0.0437854	test: 0.4087013	best: 0.3651596 (42)	total: 313ms	remaining: 5.6s
# 106:	learn: 0.0436182	test: 0.4097709	best: 0.3651596 (42)	total: 315ms	remaining: 5.57s
# 107:	learn: 0.0435693	test: 0.4094675	best: 0.3651596 (42)	total: 316ms	remaining: 5.54s
# 108:	learn: 0.0431827	test: 0.4150283	best: 0.3651596 (42)	total: 318ms	remaining: 5.51s
# 109:	learn: 0.0428690	test: 0.4159221	best: 0.3651596 (42)	total: 319ms	remaining: 5.48s
# 110:	learn: 0.0428577	test: 0.4159257	best: 0.3651596 (42)	total: 321ms	remaining: 5.46s
# 111:	learn: 0.0416666	test: 0.4192287	best: 0.3651596 (42)	total: 322ms	remaining: 5.43s
# 112:	learn: 0.0416225	test: 0.4206219	best: 0.3651596 (42)	total: 323ms	remaining: 5.4s
# 113:	learn: 0.0415180	test: 0.4212680	best: 0.3651596 (42)	total: 325ms	remaining: 5.38s
# 114:	learn: 0.0413891	test: 0.4203276	best: 0.3651596 (42)	total: 326ms	remaining: 5.35s
# 115:	learn: 0.0412459	test: 0.4211829	best: 0.3651596 (42)	total: 328ms	remaining: 5.32s
# 116:	learn: 0.0411298	test: 0.4217881	best: 0.3651596 (42)	total: 329ms	remaining: 5.3s
# 117:	learn: 0.0410070	test: 0.4221721	best: 0.3651596 (42)	total: 331ms	remaining: 5.27s
# 118:	learn: 0.0409115	test: 0.4221740	best: 0.3651596 (42)	total: 332ms	remaining: 5.25s
# 119:	learn: 0.0404830	test: 0.4236130	best: 0.3651596 (42)	total: 334ms	remaining: 5.23s
# 120:	learn: 0.0396484	test: 0.4233080	best: 0.3651596 (42)	total: 335ms	remaining: 5.21s
# 121:	learn: 0.0394988	test: 0.4225794	best: 0.3651596 (42)	total: 337ms	remaining: 5.18s
# 122:	learn: 0.0393413	test: 0.4235876	best: 0.3651596 (42)	total: 338ms	remaining: 5.16s
# 123:	learn: 0.0392338	test: 0.4232898	best: 0.3651596 (42)	total: 340ms	remaining: 5.14s
# 124:	learn: 0.0390557	test: 0.4247922	best: 0.3651596 (42)	total: 341ms	remaining: 5.12s
# 125:	learn: 0.0390556	test: 0.4247767	best: 0.3651596 (42)	total: 343ms	remaining: 5.1s
# 126:	learn: 0.0389595	test: 0.4238369	best: 0.3651596 (42)	total: 344ms	remaining: 5.07s
# 127:	learn: 0.0389111	test: 0.4252441	best: 0.3651596 (42)	total: 345ms	remaining: 5.05s
# 128:	learn: 0.0382527	test: 0.4249790	best: 0.3651596 (42)	total: 347ms	remaining: 5.03s
# 129:	learn: 0.0381671	test: 0.4256359	best: 0.3651596 (42)	total: 349ms	remaining: 5.02s
# 130:	learn: 0.0381242	test: 0.4254482	best: 0.3651596 (42)	total: 350ms	remaining: 5s
# 131:	learn: 0.0373642	test: 0.4284282	best: 0.3651596 (42)	total: 352ms	remaining: 4.98s
# 132:	learn: 0.0356749	test: 0.4257408	best: 0.3651596 (42)	total: 353ms	remaining: 4.96s
# 133:	learn: 0.0356630	test: 0.4257354	best: 0.3651596 (42)	total: 355ms	remaining: 4.94s
# 134:	learn: 0.0355492	test: 0.4253512	best: 0.3651596 (42)	total: 356ms	remaining: 4.92s
# 135:	learn: 0.0354601	test: 0.4258980	best: 0.3651596 (42)	total: 358ms	remaining: 4.9s
# 136:	learn: 0.0353712	test: 0.4256117	best: 0.3651596 (42)	total: 359ms	remaining: 4.88s
# 137:	learn: 0.0352440	test: 0.4242313	best: 0.3651596 (42)	total: 360ms	remaining: 4.86s
# 138:	learn: 0.0351828	test: 0.4248018	best: 0.3651596 (42)	total: 362ms	remaining: 4.84s
# 139:	learn: 0.0351363	test: 0.4251828	best: 0.3651596 (42)	total: 363ms	remaining: 4.83s
# 140:	learn: 0.0341390	test: 0.4290637	best: 0.3651596 (42)	total: 365ms	remaining: 4.81s
# 141:	learn: 0.0340836	test: 0.4296901	best: 0.3651596 (42)	total: 366ms	remaining: 4.79s
# 142:	learn: 0.0340279	test: 0.4301165	best: 0.3651596 (42)	total: 368ms	remaining: 4.78s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.3651595742
# bestIteration = 42
#
# Shrink model to first 43 iterations.
# [0.9217391304347826]
# ************************************ 2 ************************************
# 0:	learn: 0.5091403	test: 0.5525616	best: 0.5525616 (0)	total: 18.4ms	remaining: 36.8s
# 1:	learn: 0.4227972	test: 0.4924640	best: 0.4924640 (1)	total: 20.2ms	remaining: 20.2s
# 2:	learn: 0.3894847	test: 0.4700069	best: 0.4700069 (2)	total: 22.1ms	remaining: 14.7s
# 3:	learn: 0.3630054	test: 0.4499273	best: 0.4499273 (3)	total: 23.8ms	remaining: 11.9s
# 4:	learn: 0.3415997	test: 0.4366987	best: 0.4366987 (4)	total: 25.5ms	remaining: 10.2s
# 5:	learn: 0.3242742	test: 0.4272775	best: 0.4272775 (5)	total: 27.2ms	remaining: 9.05s
# 6:	learn: 0.2973702	test: 0.4209699	best: 0.4209699 (6)	total: 29ms	remaining: 8.25s
# 7:	learn: 0.2804234	test: 0.4095657	best: 0.4095657 (7)	total: 30.7ms	remaining: 7.64s
# 8:	learn: 0.2719653	test: 0.4190350	best: 0.4095657 (7)	total: 32.4ms	remaining: 7.17s
# 9:	learn: 0.2568955	test: 0.4237627	best: 0.4095657 (7)	total: 34.2ms	remaining: 6.8s
# 10:	learn: 0.2471635	test: 0.4207108	best: 0.4095657 (7)	total: 35.9ms	remaining: 6.49s
# 11:	learn: 0.2447731	test: 0.4196329	best: 0.4095657 (7)	total: 37.6ms	remaining: 6.24s
# 12:	learn: 0.2353333	test: 0.4260566	best: 0.4095657 (7)	total: 39.3ms	remaining: 6.01s
# 13:	learn: 0.2211972	test: 0.4202036	best: 0.4095657 (7)	total: 41ms	remaining: 5.81s
# 14:	learn: 0.2141022	test: 0.4190666	best: 0.4095657 (7)	total: 42.6ms	remaining: 5.63s
# 15:	learn: 0.1986302	test: 0.4183485	best: 0.4095657 (7)	total: 44.3ms	remaining: 5.49s
# 16:	learn: 0.1891584	test: 0.4201426	best: 0.4095657 (7)	total: 45.9ms	remaining: 5.35s
# 17:	learn: 0.1851582	test: 0.4155788	best: 0.4095657 (7)	total: 47.5ms	remaining: 5.23s
# 18:	learn: 0.1801549	test: 0.4176402	best: 0.4095657 (7)	total: 49.2ms	remaining: 5.13s
# 19:	learn: 0.1716017	test: 0.4069541	best: 0.4069541 (19)	total: 50.9ms	remaining: 5.04s
# 20:	learn: 0.1592993	test: 0.3972275	best: 0.3972275 (20)	total: 52.5ms	remaining: 4.95s
# 21:	learn: 0.1538522	test: 0.3987634	best: 0.3972275 (20)	total: 54.1ms	remaining: 4.86s
# 22:	learn: 0.1504362	test: 0.3992579	best: 0.3972275 (20)	total: 55.6ms	remaining: 4.78s
# 23:	learn: 0.1463808	test: 0.4037144	best: 0.3972275 (20)	total: 57.2ms	remaining: 4.71s
# 24:	learn: 0.1352111	test: 0.3994721	best: 0.3972275 (20)	total: 58.7ms	remaining: 4.64s
# 25:	learn: 0.1283227	test: 0.4058019	best: 0.3972275 (20)	total: 60.4ms	remaining: 4.58s
# 26:	learn: 0.1242521	test: 0.4077840	best: 0.3972275 (20)	total: 62ms	remaining: 4.53s
# 27:	learn: 0.1213695	test: 0.4098163	best: 0.3972275 (20)	total: 63.7ms	remaining: 4.49s
# 28:	learn: 0.1199154	test: 0.4115153	best: 0.3972275 (20)	total: 65.3ms	remaining: 4.44s
# 29:	learn: 0.1140823	test: 0.4140843	best: 0.3972275 (20)	total: 67.1ms	remaining: 4.41s
# 30:	learn: 0.1107953	test: 0.4152988	best: 0.3972275 (20)	total: 68.8ms	remaining: 4.37s
# 31:	learn: 0.1087189	test: 0.4156718	best: 0.3972275 (20)	total: 70.3ms	remaining: 4.32s
# 32:	learn: 0.0999661	test: 0.4188496	best: 0.3972275 (20)	total: 71.8ms	remaining: 4.28s
# 33:	learn: 0.0971247	test: 0.4196257	best: 0.3972275 (20)	total: 73.3ms	remaining: 4.24s
# 34:	learn: 0.0936823	test: 0.4243638	best: 0.3972275 (20)	total: 74.8ms	remaining: 4.2s
# 35:	learn: 0.0925784	test: 0.4245095	best: 0.3972275 (20)	total: 76.2ms	remaining: 4.16s
# 36:	learn: 0.0910773	test: 0.4164432	best: 0.3972275 (20)	total: 77.7ms	remaining: 4.12s
# 37:	learn: 0.0873581	test: 0.4172495	best: 0.3972275 (20)	total: 79.7ms	remaining: 4.12s
# 38:	learn: 0.0857749	test: 0.4184823	best: 0.3972275 (20)	total: 81.5ms	remaining: 4.1s
# 39:	learn: 0.0852055	test: 0.4137531	best: 0.3972275 (20)	total: 83.2ms	remaining: 4.08s
# 40:	learn: 0.0828315	test: 0.4187176	best: 0.3972275 (20)	total: 84.9ms	remaining: 4.06s
# 41:	learn: 0.0809442	test: 0.4212199	best: 0.3972275 (20)	total: 86.4ms	remaining: 4.03s
# 42:	learn: 0.0800632	test: 0.4190244	best: 0.3972275 (20)	total: 88ms	remaining: 4s
# 43:	learn: 0.0792963	test: 0.4198589	best: 0.3972275 (20)	total: 89.5ms	remaining: 3.98s
# 44:	learn: 0.0786962	test: 0.4200071	best: 0.3972275 (20)	total: 91ms	remaining: 3.95s
# 45:	learn: 0.0776935	test: 0.4213693	best: 0.3972275 (20)	total: 92.5ms	remaining: 3.93s
# 46:	learn: 0.0723749	test: 0.4193764	best: 0.3972275 (20)	total: 94.1ms	remaining: 3.91s
# 47:	learn: 0.0713679	test: 0.4203388	best: 0.3972275 (20)	total: 95.9ms	remaining: 3.9s
# 48:	learn: 0.0706680	test: 0.4193030	best: 0.3972275 (20)	total: 97.5ms	remaining: 3.88s
# 49:	learn: 0.0675490	test: 0.4081405	best: 0.3972275 (20)	total: 99ms	remaining: 3.86s
# 50:	learn: 0.0665160	test: 0.4091707	best: 0.3972275 (20)	total: 101ms	remaining: 3.84s
# 51:	learn: 0.0662387	test: 0.4089762	best: 0.3972275 (20)	total: 102ms	remaining: 3.82s
# 52:	learn: 0.0658452	test: 0.4101018	best: 0.3972275 (20)	total: 103ms	remaining: 3.8s
# 53:	learn: 0.0646933	test: 0.4093142	best: 0.3972275 (20)	total: 105ms	remaining: 3.78s
# 54:	learn: 0.0623640	test: 0.4123399	best: 0.3972275 (20)	total: 107ms	remaining: 3.77s
# 55:	learn: 0.0616884	test: 0.4132294	best: 0.3972275 (20)	total: 108ms	remaining: 3.75s
# 56:	learn: 0.0602972	test: 0.4178017	best: 0.3972275 (20)	total: 110ms	remaining: 3.74s
# 57:	learn: 0.0597357	test: 0.4186017	best: 0.3972275 (20)	total: 111ms	remaining: 3.73s
# 58:	learn: 0.0592807	test: 0.4192099	best: 0.3972275 (20)	total: 113ms	remaining: 3.72s
# 59:	learn: 0.0589325	test: 0.4203992	best: 0.3972275 (20)	total: 115ms	remaining: 3.71s
# 60:	learn: 0.0585292	test: 0.4198661	best: 0.3972275 (20)	total: 116ms	remaining: 3.7s
# 61:	learn: 0.0583162	test: 0.4207553	best: 0.3972275 (20)	total: 118ms	remaining: 3.69s
# 62:	learn: 0.0577753	test: 0.4210342	best: 0.3972275 (20)	total: 120ms	remaining: 3.69s
# 63:	learn: 0.0573334	test: 0.4238446	best: 0.3972275 (20)	total: 122ms	remaining: 3.68s
# 64:	learn: 0.0570318	test: 0.4251263	best: 0.3972275 (20)	total: 123ms	remaining: 3.66s
# 65:	learn: 0.0542605	test: 0.4315572	best: 0.3972275 (20)	total: 125ms	remaining: 3.65s
# 66:	learn: 0.0535522	test: 0.4315825	best: 0.3972275 (20)	total: 126ms	remaining: 3.65s
# 67:	learn: 0.0530656	test: 0.4333774	best: 0.3972275 (20)	total: 128ms	remaining: 3.64s
# 68:	learn: 0.0525431	test: 0.4399748	best: 0.3972275 (20)	total: 130ms	remaining: 3.63s
# 69:	learn: 0.0523555	test: 0.4394827	best: 0.3972275 (20)	total: 131ms	remaining: 3.62s
# 70:	learn: 0.0521486	test: 0.4392594	best: 0.3972275 (20)	total: 133ms	remaining: 3.61s
# 71:	learn: 0.0516527	test: 0.4381748	best: 0.3972275 (20)	total: 135ms	remaining: 3.61s
# 72:	learn: 0.0502522	test: 0.4434335	best: 0.3972275 (20)	total: 136ms	remaining: 3.6s
# 73:	learn: 0.0500630	test: 0.4425735	best: 0.3972275 (20)	total: 138ms	remaining: 3.59s
# 74:	learn: 0.0498021	test: 0.4431659	best: 0.3972275 (20)	total: 140ms	remaining: 3.59s
# 75:	learn: 0.0494606	test: 0.4440940	best: 0.3972275 (20)	total: 142ms	remaining: 3.59s
# 76:	learn: 0.0488045	test: 0.4462430	best: 0.3972275 (20)	total: 143ms	remaining: 3.58s
# 77:	learn: 0.0486230	test: 0.4452604	best: 0.3972275 (20)	total: 145ms	remaining: 3.58s
# 78:	learn: 0.0468676	test: 0.4394443	best: 0.3972275 (20)	total: 147ms	remaining: 3.57s
# 79:	learn: 0.0467443	test: 0.4403410	best: 0.3972275 (20)	total: 148ms	remaining: 3.56s
# 80:	learn: 0.0466367	test: 0.4409640	best: 0.3972275 (20)	total: 150ms	remaining: 3.56s
# 81:	learn: 0.0465572	test: 0.4405309	best: 0.3972275 (20)	total: 152ms	remaining: 3.55s
# 82:	learn: 0.0463378	test: 0.4413643	best: 0.3972275 (20)	total: 153ms	remaining: 3.54s
# 83:	learn: 0.0461584	test: 0.4405746	best: 0.3972275 (20)	total: 155ms	remaining: 3.53s
# 84:	learn: 0.0461387	test: 0.4404885	best: 0.3972275 (20)	total: 157ms	remaining: 3.53s
# 85:	learn: 0.0461077	test: 0.4402193	best: 0.3972275 (20)	total: 158ms	remaining: 3.52s
# 86:	learn: 0.0449872	test: 0.4434081	best: 0.3972275 (20)	total: 160ms	remaining: 3.51s
# 87:	learn: 0.0448680	test: 0.4443815	best: 0.3972275 (20)	total: 161ms	remaining: 3.51s
# 88:	learn: 0.0447542	test: 0.4450386	best: 0.3972275 (20)	total: 163ms	remaining: 3.5s
# 89:	learn: 0.0422537	test: 0.4520112	best: 0.3972275 (20)	total: 165ms	remaining: 3.49s
# 90:	learn: 0.0416028	test: 0.4540292	best: 0.3972275 (20)	total: 166ms	remaining: 3.48s
# 91:	learn: 0.0414663	test: 0.4536741	best: 0.3972275 (20)	total: 168ms	remaining: 3.48s
# 92:	learn: 0.0412363	test: 0.4525469	best: 0.3972275 (20)	total: 169ms	remaining: 3.47s
# 93:	learn: 0.0411608	test: 0.4530805	best: 0.3972275 (20)	total: 171ms	remaining: 3.46s
# 94:	learn: 0.0410187	test: 0.4539184	best: 0.3972275 (20)	total: 172ms	remaining: 3.45s
# 95:	learn: 0.0409400	test: 0.4543325	best: 0.3972275 (20)	total: 174ms	remaining: 3.44s
# 96:	learn: 0.0408321	test: 0.4554832	best: 0.3972275 (20)	total: 175ms	remaining: 3.44s
# 97:	learn: 0.0405838	test: 0.4602244	best: 0.3972275 (20)	total: 177ms	remaining: 3.43s
# 98:	learn: 0.0403779	test: 0.4612732	best: 0.3972275 (20)	total: 179ms	remaining: 3.43s
# 99:	learn: 0.0403224	test: 0.4610065	best: 0.3972275 (20)	total: 180ms	remaining: 3.42s
# 100:	learn: 0.0399197	test: 0.4623794	best: 0.3972275 (20)	total: 182ms	remaining: 3.41s
# 101:	learn: 0.0398694	test: 0.4624897	best: 0.3972275 (20)	total: 183ms	remaining: 3.4s
# 102:	learn: 0.0397109	test: 0.4649564	best: 0.3972275 (20)	total: 185ms	remaining: 3.4s
# 103:	learn: 0.0389222	test: 0.4701631	best: 0.3972275 (20)	total: 186ms	remaining: 3.39s
# 104:	learn: 0.0387624	test: 0.4702983	best: 0.3972275 (20)	total: 188ms	remaining: 3.39s
# 105:	learn: 0.0378684	test: 0.4736217	best: 0.3972275 (20)	total: 190ms	remaining: 3.39s
# 106:	learn: 0.0377548	test: 0.4742054	best: 0.3972275 (20)	total: 191ms	remaining: 3.38s
# 107:	learn: 0.0375956	test: 0.4734051	best: 0.3972275 (20)	total: 193ms	remaining: 3.38s
# 108:	learn: 0.0373406	test: 0.4748402	best: 0.3972275 (20)	total: 194ms	remaining: 3.37s
# 109:	learn: 0.0372524	test: 0.4738428	best: 0.3972275 (20)	total: 196ms	remaining: 3.36s
# 110:	learn: 0.0369811	test: 0.4756283	best: 0.3972275 (20)	total: 197ms	remaining: 3.36s
# 111:	learn: 0.0368773	test: 0.4743617	best: 0.3972275 (20)	total: 199ms	remaining: 3.35s
# 112:	learn: 0.0368689	test: 0.4739044	best: 0.3972275 (20)	total: 200ms	remaining: 3.34s
# 113:	learn: 0.0367361	test: 0.4754023	best: 0.3972275 (20)	total: 202ms	remaining: 3.34s
# 114:	learn: 0.0367148	test: 0.4742408	best: 0.3972275 (20)	total: 203ms	remaining: 3.33s
# 115:	learn: 0.0365648	test: 0.4748765	best: 0.3972275 (20)	total: 205ms	remaining: 3.33s
# 116:	learn: 0.0364710	test: 0.4751379	best: 0.3972275 (20)	total: 207ms	remaining: 3.33s
# 117:	learn: 0.0363776	test: 0.4753707	best: 0.3972275 (20)	total: 208ms	remaining: 3.32s
# 118:	learn: 0.0363001	test: 0.4745862	best: 0.3972275 (20)	total: 210ms	remaining: 3.32s
# 119:	learn: 0.0354483	test: 0.4757902	best: 0.3972275 (20)	total: 212ms	remaining: 3.32s
# 120:	learn: 0.0353937	test: 0.4760059	best: 0.3972275 (20)	total: 213ms	remaining: 3.31s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.3972275316
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# [0.9217391304347826, 0.8817204301075269]
# ************************************ 3 ************************************
# 0:	learn: 0.5376760	test: 0.5260424	best: 0.5260424 (0)	total: 2ms	remaining: 4s
# 1:	learn: 0.4338387	test: 0.3753978	best: 0.3753978 (1)	total: 3.77ms	remaining: 3.77s
# 2:	learn: 0.3921607	test: 0.3494275	best: 0.3494275 (2)	total: 5.5ms	remaining: 3.66s
# 3:	learn: 0.3522596	test: 0.3392995	best: 0.3392995 (3)	total: 7.11ms	remaining: 3.54s
# 4:	learn: 0.3338583	test: 0.3360402	best: 0.3360402 (4)	total: 8.57ms	remaining: 3.42s
# 5:	learn: 0.3174836	test: 0.3326291	best: 0.3326291 (5)	total: 10.3ms	remaining: 3.43s
# 6:	learn: 0.3049791	test: 0.3346554	best: 0.3326291 (5)	total: 12ms	remaining: 3.43s
# 7:	learn: 0.2908674	test: 0.3327670	best: 0.3326291 (5)	total: 13.8ms	remaining: 3.44s
# 8:	learn: 0.2814227	test: 0.3217547	best: 0.3217547 (8)	total: 15.7ms	remaining: 3.48s
# 9:	learn: 0.2782536	test: 0.3220585	best: 0.3217547 (8)	total: 17.2ms	remaining: 3.43s
# 10:	learn: 0.2553937	test: 0.3156978	best: 0.3156978 (10)	total: 18.7ms	remaining: 3.38s
# 11:	learn: 0.2460854	test: 0.3226120	best: 0.3156978 (10)	total: 20.2ms	remaining: 3.35s
# 12:	learn: 0.2285174	test: 0.3037397	best: 0.3037397 (12)	total: 21.8ms	remaining: 3.34s
# 13:	learn: 0.2236289	test: 0.3032852	best: 0.3032852 (13)	total: 23.4ms	remaining: 3.32s
# 14:	learn: 0.2134735	test: 0.3027605	best: 0.3027605 (14)	total: 24.9ms	remaining: 3.3s
# 15:	learn: 0.2059121	test: 0.3041138	best: 0.3027605 (14)	total: 26.6ms	remaining: 3.29s
# 16:	learn: 0.1972453	test: 0.3023301	best: 0.3023301 (16)	total: 28.1ms	remaining: 3.28s
# 17:	learn: 0.1914424	test: 0.2832866	best: 0.2832866 (17)	total: 29.6ms	remaining: 3.26s
# 18:	learn: 0.1861362	test: 0.2806014	best: 0.2806014 (18)	total: 31.1ms	remaining: 3.24s
# 19:	learn: 0.1793827	test: 0.2747721	best: 0.2747721 (19)	total: 32.5ms	remaining: 3.22s
# 20:	learn: 0.1749697	test: 0.2718796	best: 0.2718796 (20)	total: 33.9ms	remaining: 3.2s
# 21:	learn: 0.1678564	test: 0.2761550	best: 0.2718796 (20)	total: 35.3ms	remaining: 3.18s
# 22:	learn: 0.1614315	test: 0.2769057	best: 0.2718796 (20)	total: 36.7ms	remaining: 3.15s
# 23:	learn: 0.1576420	test: 0.2672651	best: 0.2672651 (23)	total: 38.1ms	remaining: 3.14s
# 24:	learn: 0.1473361	test: 0.2620446	best: 0.2620446 (24)	total: 39.6ms	remaining: 3.13s
# 25:	learn: 0.1437469	test: 0.2557743	best: 0.2557743 (25)	total: 40.9ms	remaining: 3.11s
# 26:	learn: 0.1384360	test: 0.2543039	best: 0.2543039 (26)	total: 42.5ms	remaining: 3.11s
# 27:	learn: 0.1358924	test: 0.2498189	best: 0.2498189 (27)	total: 44ms	remaining: 3.1s
# 28:	learn: 0.1326281	test: 0.2522821	best: 0.2498189 (27)	total: 45.4ms	remaining: 3.08s
# 29:	learn: 0.1278950	test: 0.2505062	best: 0.2498189 (27)	total: 46.8ms	remaining: 3.08s
# 30:	learn: 0.1218342	test: 0.2437082	best: 0.2437082 (30)	total: 48.3ms	remaining: 3.06s
# 31:	learn: 0.1180656	test: 0.2444661	best: 0.2437082 (30)	total: 49.7ms	remaining: 3.06s
# 32:	learn: 0.1130684	test: 0.2487038	best: 0.2437082 (30)	total: 51.1ms	remaining: 3.04s
# 33:	learn: 0.1114468	test: 0.2478332	best: 0.2437082 (30)	total: 52.5ms	remaining: 3.03s
# 34:	learn: 0.1095861	test: 0.2458033	best: 0.2437082 (30)	total: 53.9ms	remaining: 3.02s
# 35:	learn: 0.1078304	test: 0.2466643	best: 0.2437082 (30)	total: 55.3ms	remaining: 3.02s
# 36:	learn: 0.1002077	test: 0.2421447	best: 0.2421447 (36)	total: 56.9ms	remaining: 3.02s
# 37:	learn: 0.0983923	test: 0.2357503	best: 0.2357503 (37)	total: 58.4ms	remaining: 3.01s
# 38:	learn: 0.0968352	test: 0.2362853	best: 0.2357503 (37)	total: 59.8ms	remaining: 3s
# 39:	learn: 0.0950739	test: 0.2400343	best: 0.2357503 (37)	total: 61.1ms	remaining: 3s
# 40:	learn: 0.0926664	test: 0.2400340	best: 0.2357503 (37)	total: 62.5ms	remaining: 2.99s
# 41:	learn: 0.0882741	test: 0.2489470	best: 0.2357503 (37)	total: 64.1ms	remaining: 2.99s
# 42:	learn: 0.0876993	test: 0.2486011	best: 0.2357503 (37)	total: 65.5ms	remaining: 2.98s
# 43:	learn: 0.0864424	test: 0.2492430	best: 0.2357503 (37)	total: 66.9ms	remaining: 2.97s
# 44:	learn: 0.0853456	test: 0.2444939	best: 0.2357503 (37)	total: 68.3ms	remaining: 2.97s
# 45:	learn: 0.0846957	test: 0.2392665	best: 0.2357503 (37)	total: 69.7ms	remaining: 2.96s
# 46:	learn: 0.0833186	test: 0.2404493	best: 0.2357503 (37)	total: 71ms	remaining: 2.95s
# 47:	learn: 0.0824667	test: 0.2389593	best: 0.2357503 (37)	total: 72.5ms	remaining: 2.95s
# 48:	learn: 0.0806621	test: 0.2365053	best: 0.2357503 (37)	total: 73.9ms	remaining: 2.94s
# 49:	learn: 0.0790678	test: 0.2374789	best: 0.2357503 (37)	total: 75.3ms	remaining: 2.94s
# 50:	learn: 0.0784527	test: 0.2344549	best: 0.2344549 (50)	total: 76.7ms	remaining: 2.93s
# 51:	learn: 0.0773132	test: 0.2348214	best: 0.2344549 (50)	total: 78.2ms	remaining: 2.93s
# 52:	learn: 0.0763999	test: 0.2346141	best: 0.2344549 (50)	total: 79.6ms	remaining: 2.92s
# 53:	learn: 0.0755501	test: 0.2326137	best: 0.2326137 (53)	total: 81.1ms	remaining: 2.92s
# 54:	learn: 0.0745364	test: 0.2328032	best: 0.2326137 (53)	total: 82.5ms	remaining: 2.92s
# 55:	learn: 0.0741108	test: 0.2317401	best: 0.2317401 (55)	total: 84ms	remaining: 2.92s
# 56:	learn: 0.0716294	test: 0.2245198	best: 0.2245198 (56)	total: 85.4ms	remaining: 2.91s
# 57:	learn: 0.0712751	test: 0.2268246	best: 0.2245198 (56)	total: 86.8ms	remaining: 2.9s
# 58:	learn: 0.0702937	test: 0.2271639	best: 0.2245198 (56)	total: 88.3ms	remaining: 2.91s
# 59:	learn: 0.0696954	test: 0.2258641	best: 0.2245198 (56)	total: 89.7ms	remaining: 2.9s
# 60:	learn: 0.0692129	test: 0.2279821	best: 0.2245198 (56)	total: 91.2ms	remaining: 2.9s
# 61:	learn: 0.0658582	test: 0.2277394	best: 0.2245198 (56)	total: 92.6ms	remaining: 2.89s
# 62:	learn: 0.0646826	test: 0.2269508	best: 0.2245198 (56)	total: 94ms	remaining: 2.89s
# 63:	learn: 0.0599273	test: 0.2214758	best: 0.2214758 (63)	total: 95.3ms	remaining: 2.88s
# 64:	learn: 0.0593376	test: 0.2212038	best: 0.2212038 (64)	total: 96.8ms	remaining: 2.88s
# 65:	learn: 0.0582770	test: 0.2190181	best: 0.2190181 (65)	total: 98.2ms	remaining: 2.88s
# 66:	learn: 0.0579109	test: 0.2187312	best: 0.2187312 (66)	total: 99.6ms	remaining: 2.87s
# 67:	learn: 0.0575214	test: 0.2204491	best: 0.2187312 (66)	total: 101ms	remaining: 2.87s
# 68:	learn: 0.0542097	test: 0.2179670	best: 0.2179670 (68)	total: 102ms	remaining: 2.87s
# 69:	learn: 0.0525318	test: 0.2226530	best: 0.2179670 (68)	total: 104ms	remaining: 2.86s
# 70:	learn: 0.0521673	test: 0.2226013	best: 0.2179670 (68)	total: 105ms	remaining: 2.86s
# 71:	learn: 0.0517785	test: 0.2222511	best: 0.2179670 (68)	total: 107ms	remaining: 2.87s
# 72:	learn: 0.0511054	test: 0.2222163	best: 0.2179670 (68)	total: 109ms	remaining: 2.87s
# 73:	learn: 0.0504710	test: 0.2225348	best: 0.2179670 (68)	total: 110ms	remaining: 2.87s
# 74:	learn: 0.0501495	test: 0.2208549	best: 0.2179670 (68)	total: 112ms	remaining: 2.87s
# 75:	learn: 0.0494252	test: 0.2210677	best: 0.2179670 (68)	total: 114ms	remaining: 2.87s
# 76:	learn: 0.0492205	test: 0.2227214	best: 0.2179670 (68)	total: 115ms	remaining: 2.87s
# 77:	learn: 0.0487134	test: 0.2226727	best: 0.2179670 (68)	total: 117ms	remaining: 2.87s
# 78:	learn: 0.0485693	test: 0.2227376	best: 0.2179670 (68)	total: 118ms	remaining: 2.87s
# 79:	learn: 0.0482921	test: 0.2229551	best: 0.2179670 (68)	total: 120ms	remaining: 2.87s
# 80:	learn: 0.0470172	test: 0.2255679	best: 0.2179670 (68)	total: 121ms	remaining: 2.88s
# 81:	learn: 0.0464667	test: 0.2261140	best: 0.2179670 (68)	total: 123ms	remaining: 2.88s
# 82:	learn: 0.0461004	test: 0.2256168	best: 0.2179670 (68)	total: 125ms	remaining: 2.88s
# 83:	learn: 0.0459140	test: 0.2269802	best: 0.2179670 (68)	total: 126ms	remaining: 2.88s
# 84:	learn: 0.0457382	test: 0.2266469	best: 0.2179670 (68)	total: 128ms	remaining: 2.88s
# 85:	learn: 0.0456180	test: 0.2268564	best: 0.2179670 (68)	total: 130ms	remaining: 2.88s
# 86:	learn: 0.0453620	test: 0.2253936	best: 0.2179670 (68)	total: 131ms	remaining: 2.89s
# 87:	learn: 0.0451711	test: 0.2253132	best: 0.2179670 (68)	total: 133ms	remaining: 2.89s
# 88:	learn: 0.0430208	test: 0.2324101	best: 0.2179670 (68)	total: 134ms	remaining: 2.88s
# 89:	learn: 0.0420263	test: 0.2328281	best: 0.2179670 (68)	total: 136ms	remaining: 2.88s
# 90:	learn: 0.0417888	test: 0.2334581	best: 0.2179670 (68)	total: 137ms	remaining: 2.88s
# 91:	learn: 0.0402294	test: 0.2321171	best: 0.2179670 (68)	total: 139ms	remaining: 2.88s
# 92:	learn: 0.0399208	test: 0.2307163	best: 0.2179670 (68)	total: 140ms	remaining: 2.87s
# 93:	learn: 0.0397791	test: 0.2304404	best: 0.2179670 (68)	total: 141ms	remaining: 2.87s
# 94:	learn: 0.0396448	test: 0.2301269	best: 0.2179670 (68)	total: 143ms	remaining: 2.87s
# 95:	learn: 0.0384909	test: 0.2243311	best: 0.2179670 (68)	total: 144ms	remaining: 2.86s
# 96:	learn: 0.0383507	test: 0.2254235	best: 0.2179670 (68)	total: 146ms	remaining: 2.86s
# 97:	learn: 0.0382172	test: 0.2250544	best: 0.2179670 (68)	total: 147ms	remaining: 2.85s
# 98:	learn: 0.0379201	test: 0.2251519	best: 0.2179670 (68)	total: 149ms	remaining: 2.85s
# 99:	learn: 0.0376688	test: 0.2248569	best: 0.2179670 (68)	total: 150ms	remaining: 2.85s
# 100:	learn: 0.0375387	test: 0.2266946	best: 0.2179670 (68)	total: 151ms	remaining: 2.85s
# 101:	learn: 0.0371508	test: 0.2249418	best: 0.2179670 (68)	total: 153ms	remaining: 2.84s
# 102:	learn: 0.0370073	test: 0.2246247	best: 0.2179670 (68)	total: 154ms	remaining: 2.84s
# 103:	learn: 0.0364337	test: 0.2249600	best: 0.2179670 (68)	total: 156ms	remaining: 2.84s
# 104:	learn: 0.0362885	test: 0.2240036	best: 0.2179670 (68)	total: 157ms	remaining: 2.83s
# 105:	learn: 0.0361548	test: 0.2234345	best: 0.2179670 (68)	total: 158ms	remaining: 2.83s
# 106:	learn: 0.0351356	test: 0.2257414	best: 0.2179670 (68)	total: 160ms	remaining: 2.83s
# 107:	learn: 0.0349500	test: 0.2260802	best: 0.2179670 (68)	total: 161ms	remaining: 2.82s
# 108:	learn: 0.0348089	test: 0.2274264	best: 0.2179670 (68)	total: 163ms	remaining: 2.82s
# 109:	learn: 0.0341318	test: 0.2290761	best: 0.2179670 (68)	total: 164ms	remaining: 2.82s
# 110:	learn: 0.0339913	test: 0.2289255	best: 0.2179670 (68)	total: 165ms	remaining: 2.81s
# 111:	learn: 0.0338804	test: 0.2288172	best: 0.2179670 (68)	total: 167ms	remaining: 2.81s
# 112:	learn: 0.0337810	test: 0.2283630	best: 0.2179670 (68)	total: 168ms	remaining: 2.81s
# 113:	learn: 0.0328958	test: 0.2275254	best: 0.2179670 (68)	total: 170ms	remaining: 2.81s
# 114:	learn: 0.0327695	test: 0.2291431	best: 0.2179670 (68)	total: 171ms	remaining: 2.8s
# 115:	learn: 0.0325501	test: 0.2294124	best: 0.2179670 (68)	total: 173ms	remaining: 2.8s
# 116:	learn: 0.0324502	test: 0.2295960	best: 0.2179670 (68)	total: 174ms	remaining: 2.8s
# 117:	learn: 0.0323449	test: 0.2304267	best: 0.2179670 (68)	total: 175ms	remaining: 2.8s
# 118:	learn: 0.0322191	test: 0.2307332	best: 0.2179670 (68)	total: 177ms	remaining: 2.79s
# 119:	learn: 0.0310667	test: 0.2350314	best: 0.2179670 (68)	total: 178ms	remaining: 2.79s
# 120:	learn: 0.0303238	test: 0.2400737	best: 0.2179670 (68)	total: 180ms	remaining: 2.79s
# 121:	learn: 0.0302154	test: 0.2397610	best: 0.2179670 (68)	total: 181ms	remaining: 2.79s
# 122:	learn: 0.0301242	test: 0.2387543	best: 0.2179670 (68)	total: 182ms	remaining: 2.78s
# 123:	learn: 0.0300311	test: 0.2389959	best: 0.2179670 (68)	total: 184ms	remaining: 2.78s
# 124:	learn: 0.0299562	test: 0.2388489	best: 0.2179670 (68)	total: 185ms	remaining: 2.78s
# 125:	learn: 0.0298612	test: 0.2391219	best: 0.2179670 (68)	total: 187ms	remaining: 2.78s
# 126:	learn: 0.0296886	test: 0.2384025	best: 0.2179670 (68)	total: 188ms	remaining: 2.77s
# 127:	learn: 0.0287440	test: 0.2334400	best: 0.2179670 (68)	total: 189ms	remaining: 2.77s
# 128:	learn: 0.0286739	test: 0.2336331	best: 0.2179670 (68)	total: 191ms	remaining: 2.77s
# 129:	learn: 0.0286017	test: 0.2337375	best: 0.2179670 (68)	total: 192ms	remaining: 2.77s
# 130:	learn: 0.0285027	test: 0.2339718	best: 0.2179670 (68)	total: 194ms	remaining: 2.76s
# 131:	learn: 0.0281733	test: 0.2343699	best: 0.2179670 (68)	total: 195ms	remaining: 2.76s
# 132:	learn: 0.0279974	test: 0.2345749	best: 0.2179670 (68)	total: 197ms	remaining: 2.76s
# 133:	learn: 0.0279126	test: 0.2338985	best: 0.2179670 (68)	total: 198ms	remaining: 2.76s
# 134:	learn: 0.0277206	test: 0.2337864	best: 0.2179670 (68)	total: 199ms	remaining: 2.75s
# 135:	learn: 0.0276087	test: 0.2344557	best: 0.2179670 (68)	total: 201ms	remaining: 2.75s
# 136:	learn: 0.0272888	test: 0.2347326	best: 0.2179670 (68)	total: 202ms	remaining: 2.75s
# 137:	learn: 0.0272159	test: 0.2346993	best: 0.2179670 (68)	total: 204ms	remaining: 2.75s
# 138:	learn: 0.0271417	test: 0.2346832	best: 0.2179670 (68)	total: 205ms	remaining: 2.74s
# 139:	learn: 0.0262383	test: 0.2367914	best: 0.2179670 (68)	total: 206ms	remaining: 2.74s
# 140:	learn: 0.0261047	test: 0.2369535	best: 0.2179670 (68)	total: 208ms	remaining: 2.74s
# 141:	learn: 0.0260072	test: 0.2371826	best: 0.2179670 (68)	total: 209ms	remaining: 2.73s
# 142:	learn: 0.0255486	test: 0.2387399	best: 0.2179670 (68)	total: 210ms	remaining: 2.73s
# 143:	learn: 0.0254509	test: 0.2392307	best: 0.2179670 (68)	total: 212ms	remaining: 2.74s
# 144:	learn: 0.0253415	test: 0.2394029	best: 0.2179670 (68)	total: 214ms	remaining: 2.74s
# 145:	learn: 0.0252869	test: 0.2390558	best: 0.2179670 (68)	total: 216ms	remaining: 2.74s
# 146:	learn: 0.0246250	test: 0.2352700	best: 0.2179670 (68)	total: 217ms	remaining: 2.74s
# 147:	learn: 0.0242922	test: 0.2382571	best: 0.2179670 (68)	total: 219ms	remaining: 2.74s
# 148:	learn: 0.0242553	test: 0.2379161	best: 0.2179670 (68)	total: 220ms	remaining: 2.73s
# 149:	learn: 0.0241963	test: 0.2380243	best: 0.2179670 (68)	total: 222ms	remaining: 2.73s
# 150:	learn: 0.0240695	test: 0.2380467	best: 0.2179670 (68)	total: 223ms	remaining: 2.73s
# 151:	learn: 0.0240031	test: 0.2381909	best: 0.2179670 (68)	total: 224ms	remaining: 2.73s
# 152:	learn: 0.0237438	test: 0.2394330	best: 0.2179670 (68)	total: 226ms	remaining: 2.73s
# 153:	learn: 0.0237011	test: 0.2397236	best: 0.2179670 (68)	total: 227ms	remaining: 2.72s
# 154:	learn: 0.0235316	test: 0.2391767	best: 0.2179670 (68)	total: 229ms	remaining: 2.72s
# 155:	learn: 0.0234846	test: 0.2391443	best: 0.2179670 (68)	total: 230ms	remaining: 2.72s
# 156:	learn: 0.0233636	test: 0.2392874	best: 0.2179670 (68)	total: 232ms	remaining: 2.72s
# 157:	learn: 0.0233108	test: 0.2387732	best: 0.2179670 (68)	total: 233ms	remaining: 2.72s
# 158:	learn: 0.0232677	test: 0.2387423	best: 0.2179670 (68)	total: 235ms	remaining: 2.72s
# 159:	learn: 0.0231995	test: 0.2378792	best: 0.2179670 (68)	total: 236ms	remaining: 2.72s
# 160:	learn: 0.0231689	test: 0.2378250	best: 0.2179670 (68)	total: 238ms	remaining: 2.72s
# 161:	learn: 0.0227361	test: 0.2409376	best: 0.2179670 (68)	total: 239ms	remaining: 2.71s
# 162:	learn: 0.0226844	test: 0.2404385	best: 0.2179670 (68)	total: 241ms	remaining: 2.71s
# 163:	learn: 0.0220744	test: 0.2392514	best: 0.2179670 (68)	total: 242ms	remaining: 2.71s
# 164:	learn: 0.0220001	test: 0.2391591	best: 0.2179670 (68)	total: 244ms	remaining: 2.71s
# 165:	learn: 0.0218456	test: 0.2387151	best: 0.2179670 (68)	total: 246ms	remaining: 2.71s
# 166:	learn: 0.0218196	test: 0.2396350	best: 0.2179670 (68)	total: 247ms	remaining: 2.71s
# 167:	learn: 0.0216147	test: 0.2395865	best: 0.2179670 (68)	total: 249ms	remaining: 2.71s
# 168:	learn: 0.0215587	test: 0.2397766	best: 0.2179670 (68)	total: 250ms	remaining: 2.71s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2179670127
# bestIteration = 68
#
# Shrink model to first 69 iterations.
# [0.9217391304347826, 0.8817204301075269, 0.9176470588235294]
# ************************************ 4 ************************************
# 0:	learn: 0.5084263	test: 0.5427916	best: 0.5427916 (0)	total: 2.58ms	remaining: 5.16s
# 1:	learn: 0.4269557	test: 0.5167249	best: 0.5167249 (1)	total: 4.66ms	remaining: 4.66s
# 2:	learn: 0.3735834	test: 0.5071901	best: 0.5071901 (2)	total: 6.55ms	remaining: 4.36s
# 3:	learn: 0.3427388	test: 0.4957751	best: 0.4957751 (3)	total: 8.49ms	remaining: 4.23s
# 4:	learn: 0.3281622	test: 0.4828225	best: 0.4828225 (4)	total: 10.6ms	remaining: 4.24s
# 5:	learn: 0.3107680	test: 0.4752517	best: 0.4752517 (5)	total: 12.4ms	remaining: 4.12s
# 6:	learn: 0.2991985	test: 0.4842648	best: 0.4752517 (5)	total: 14.1ms	remaining: 4.02s
# 7:	learn: 0.2879891	test: 0.4859500	best: 0.4752517 (5)	total: 15.8ms	remaining: 3.94s
# 8:	learn: 0.2815039	test: 0.4791182	best: 0.4752517 (5)	total: 17.4ms	remaining: 3.85s
# 9:	learn: 0.2618950	test: 0.4652992	best: 0.4652992 (9)	total: 18.9ms	remaining: 3.77s
# 10:	learn: 0.2569981	test: 0.4630494	best: 0.4630494 (10)	total: 20.5ms	remaining: 3.71s
# 11:	learn: 0.2464451	test: 0.4723504	best: 0.4630494 (10)	total: 22ms	remaining: 3.65s
# 12:	learn: 0.2348944	test: 0.4737813	best: 0.4630494 (10)	total: 23.5ms	remaining: 3.6s
# 13:	learn: 0.2258378	test: 0.4762556	best: 0.4630494 (10)	total: 25.2ms	remaining: 3.57s
# 14:	learn: 0.2169953	test: 0.4673428	best: 0.4630494 (10)	total: 26.8ms	remaining: 3.55s
# 15:	learn: 0.2028165	test: 0.4428481	best: 0.4428481 (15)	total: 28.6ms	remaining: 3.54s
# 16:	learn: 0.1952008	test: 0.4474766	best: 0.4428481 (15)	total: 30.2ms	remaining: 3.53s
# 17:	learn: 0.1885193	test: 0.4473192	best: 0.4428481 (15)	total: 31.9ms	remaining: 3.51s
# 18:	learn: 0.1857819	test: 0.4455555	best: 0.4428481 (15)	total: 33.4ms	remaining: 3.48s
# 19:	learn: 0.1776389	test: 0.4422907	best: 0.4422907 (19)	total: 35ms	remaining: 3.47s
# 20:	learn: 0.1755091	test: 0.4394248	best: 0.4394248 (20)	total: 36.8ms	remaining: 3.47s
# 21:	learn: 0.1690586	test: 0.4435646	best: 0.4394248 (20)	total: 38.4ms	remaining: 3.45s
# 22:	learn: 0.1646003	test: 0.4396664	best: 0.4394248 (20)	total: 39.9ms	remaining: 3.43s
# 23:	learn: 0.1594750	test: 0.4418511	best: 0.4394248 (20)	total: 41.5ms	remaining: 3.42s
# 24:	learn: 0.1551550	test: 0.4431122	best: 0.4394248 (20)	total: 43.3ms	remaining: 3.42s
# 25:	learn: 0.1520399	test: 0.4432889	best: 0.4394248 (20)	total: 44.8ms	remaining: 3.4s
# 26:	learn: 0.1492231	test: 0.4463199	best: 0.4394248 (20)	total: 46.3ms	remaining: 3.38s
# 27:	learn: 0.1469705	test: 0.4497454	best: 0.4394248 (20)	total: 47.8ms	remaining: 3.37s
# 28:	learn: 0.1347549	test: 0.4477230	best: 0.4394248 (20)	total: 49.4ms	remaining: 3.36s
# 29:	learn: 0.1292288	test: 0.4399675	best: 0.4394248 (20)	total: 50.8ms	remaining: 3.34s
# 30:	learn: 0.1269686	test: 0.4397864	best: 0.4394248 (20)	total: 52.4ms	remaining: 3.33s
# 31:	learn: 0.1194663	test: 0.4356448	best: 0.4356448 (31)	total: 54ms	remaining: 3.32s
# 32:	learn: 0.1173561	test: 0.4376190	best: 0.4356448 (31)	total: 55.8ms	remaining: 3.32s
# 33:	learn: 0.1154502	test: 0.4392750	best: 0.4356448 (31)	total: 57.5ms	remaining: 3.32s
# 34:	learn: 0.1142205	test: 0.4372118	best: 0.4356448 (31)	total: 59.2ms	remaining: 3.32s
# 35:	learn: 0.1130002	test: 0.4362272	best: 0.4356448 (31)	total: 60.9ms	remaining: 3.32s
# 36:	learn: 0.1086925	test: 0.4310498	best: 0.4310498 (36)	total: 62.5ms	remaining: 3.32s
# 37:	learn: 0.1077065	test: 0.4313768	best: 0.4310498 (36)	total: 64ms	remaining: 3.31s
# 38:	learn: 0.1020163	test: 0.4301090	best: 0.4301090 (38)	total: 65.6ms	remaining: 3.3s
# 39:	learn: 0.1005513	test: 0.4323069	best: 0.4301090 (38)	total: 67.3ms	remaining: 3.29s
# 40:	learn: 0.0950996	test: 0.4317973	best: 0.4301090 (38)	total: 69.1ms	remaining: 3.3s
# 41:	learn: 0.0915913	test: 0.4298232	best: 0.4298232 (41)	total: 70.6ms	remaining: 3.29s
# 42:	learn: 0.0900076	test: 0.4319696	best: 0.4298232 (41)	total: 72.1ms	remaining: 3.28s
# 43:	learn: 0.0898212	test: 0.4317708	best: 0.4298232 (41)	total: 73.6ms	remaining: 3.27s
# 44:	learn: 0.0869877	test: 0.4318337	best: 0.4298232 (41)	total: 75.1ms	remaining: 3.26s
# 45:	learn: 0.0854798	test: 0.4350634	best: 0.4298232 (41)	total: 76.7ms	remaining: 3.26s
# 46:	learn: 0.0845276	test: 0.4355311	best: 0.4298232 (41)	total: 78.5ms	remaining: 3.26s
# 47:	learn: 0.0833601	test: 0.4359118	best: 0.4298232 (41)	total: 80.2ms	remaining: 3.26s
# 48:	learn: 0.0776490	test: 0.4133279	best: 0.4133279 (48)	total: 81.9ms	remaining: 3.26s
# 49:	learn: 0.0761802	test: 0.4143650	best: 0.4133279 (48)	total: 83.6ms	remaining: 3.26s
# 50:	learn: 0.0741541	test: 0.4167869	best: 0.4133279 (48)	total: 85.2ms	remaining: 3.26s
# 51:	learn: 0.0732837	test: 0.4129746	best: 0.4129746 (51)	total: 86.9ms	remaining: 3.25s
# 52:	learn: 0.0723247	test: 0.4161558	best: 0.4129746 (51)	total: 88.5ms	remaining: 3.25s
# 53:	learn: 0.0702738	test: 0.4179303	best: 0.4129746 (51)	total: 90.1ms	remaining: 3.25s
# 54:	learn: 0.0662279	test: 0.4280374	best: 0.4129746 (51)	total: 91.7ms	remaining: 3.24s
# 55:	learn: 0.0620222	test: 0.4312242	best: 0.4129746 (51)	total: 93.4ms	remaining: 3.24s
# 56:	learn: 0.0613954	test: 0.4337681	best: 0.4129746 (51)	total: 95.1ms	remaining: 3.24s
# 57:	learn: 0.0591388	test: 0.4334897	best: 0.4129746 (51)	total: 96.7ms	remaining: 3.24s
# 58:	learn: 0.0582396	test: 0.4345410	best: 0.4129746 (51)	total: 98.3ms	remaining: 3.23s
# 59:	learn: 0.0577856	test: 0.4349719	best: 0.4129746 (51)	total: 100ms	remaining: 3.24s
# 60:	learn: 0.0571773	test: 0.4354886	best: 0.4129746 (51)	total: 102ms	remaining: 3.24s
# 61:	learn: 0.0567185	test: 0.4365353	best: 0.4129746 (51)	total: 104ms	remaining: 3.24s
# 62:	learn: 0.0562661	test: 0.4383907	best: 0.4129746 (51)	total: 105ms	remaining: 3.24s
# 63:	learn: 0.0560025	test: 0.4383281	best: 0.4129746 (51)	total: 107ms	remaining: 3.24s
# 64:	learn: 0.0552756	test: 0.4384366	best: 0.4129746 (51)	total: 109ms	remaining: 3.24s
# 65:	learn: 0.0539506	test: 0.4411745	best: 0.4129746 (51)	total: 111ms	remaining: 3.24s
# 66:	learn: 0.0536360	test: 0.4406175	best: 0.4129746 (51)	total: 112ms	remaining: 3.24s
# 67:	learn: 0.0531591	test: 0.4405662	best: 0.4129746 (51)	total: 114ms	remaining: 3.24s
# 68:	learn: 0.0506363	test: 0.4481480	best: 0.4129746 (51)	total: 116ms	remaining: 3.24s
# 69:	learn: 0.0476860	test: 0.4367774	best: 0.4129746 (51)	total: 117ms	remaining: 3.23s
# ...
# 135:	learn: 0.0248077	test: 0.4953705	best: 0.4129746 (51)	total: 217ms	remaining: 2.98s
# 136:	learn: 0.0247267	test: 0.4948080	best: 0.4129746 (51)	total: 219ms	remaining: 2.98s
# 137:	learn: 0.0244938	test: 0.4931408	best: 0.4129746 (51)	total: 220ms	remaining: 2.97s
# 138:	learn: 0.0242785	test: 0.4943505	best: 0.4129746 (51)	total: 222ms	remaining: 2.97s
# 139:	learn: 0.0242039	test: 0.4961099	best: 0.4129746 (51)	total: 224ms	remaining: 2.97s
# 140:	learn: 0.0241674	test: 0.4964394	best: 0.4129746 (51)	total: 225ms	remaining: 2.97s
# 141:	learn: 0.0239158	test: 0.4989175	best: 0.4129746 (51)	total: 227ms	remaining: 2.97s
# 142:	learn: 0.0238218	test: 0.4976429	best: 0.4129746 (51)	total: 228ms	remaining: 2.96s
# 143:	learn: 0.0236802	test: 0.4967417	best: 0.4129746 (51)	total: 230ms	remaining: 2.96s
# 144:	learn: 0.0229772	test: 0.5006361	best: 0.4129746 (51)	total: 231ms	remaining: 2.96s
# 145:	learn: 0.0228377	test: 0.5007794	best: 0.4129746 (51)	total: 233ms	remaining: 2.95s
# 146:	learn: 0.0227586	test: 0.5019711	best: 0.4129746 (51)	total: 234ms	remaining: 2.95s
# 147:	learn: 0.0223886	test: 0.5033823	best: 0.4129746 (51)	total: 236ms	remaining: 2.95s
# 148:	learn: 0.0217941	test: 0.5066508	best: 0.4129746 (51)	total: 237ms	remaining: 2.94s
# 149:	learn: 0.0216708	test: 0.5080931	best: 0.4129746 (51)	total: 238ms	remaining: 2.94s
# 150:	learn: 0.0216248	test: 0.5076731	best: 0.4129746 (51)	total: 240ms	remaining: 2.94s
# 151:	learn: 0.0216000	test: 0.5062912	best: 0.4129746 (51)	total: 242ms	remaining: 2.94s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.4129745768
# bestIteration = 51
#
# Shrink model to first 52 iterations.
# [0.9217391304347826, 0.8817204301075269, 0.9176470588235294, 0.8717948717948718]
# ************************************ 5 ************************************
# 0:	learn: 0.5498294	test: 0.5036611	best: 0.5036611 (0)	total: 1.85ms	remaining: 3.71s
# 1:	learn: 0.4598359	test: 0.4404026	best: 0.4404026 (1)	total: 3.62ms	remaining: 3.61s
# 2:	learn: 0.4343677	test: 0.4126854	best: 0.4126854 (2)	total: 4.58ms	remaining: 3.05s
# 3:	learn: 0.3943572	test: 0.4157999	best: 0.4126854 (2)	total: 6.2ms	remaining: 3.09s
# 4:	learn: 0.3768097	test: 0.4107886	best: 0.4107886 (4)	total: 7.72ms	remaining: 3.08s
# 5:	learn: 0.3450295	test: 0.4094481	best: 0.4094481 (5)	total: 9.17ms	remaining: 3.05s
# 6:	learn: 0.3365350	test: 0.4012703	best: 0.4012703 (6)	total: 10.7ms	remaining: 3.04s
# 7:	learn: 0.3222726	test: 0.3965411	best: 0.3965411 (7)	total: 12.3ms	remaining: 3.06s
# 8:	learn: 0.3096434	test: 0.3946571	best: 0.3946571 (8)	total: 13.8ms	remaining: 3.05s
# 9:	learn: 0.2909044	test: 0.3702620	best: 0.3702620 (9)	total: 15.3ms	remaining: 3.04s
# 10:	learn: 0.2810733	test: 0.3812655	best: 0.3702620 (9)	total: 16.9ms	remaining: 3.06s
# 11:	learn: 0.2723017	test: 0.3926706	best: 0.3702620 (9)	total: 18.4ms	remaining: 3.05s
# 12:	learn: 0.2625739	test: 0.3816750	best: 0.3702620 (9)	total: 19.7ms	remaining: 3.01s
# 13:	learn: 0.2527321	test: 0.3750671	best: 0.3702620 (9)	total: 21.2ms	remaining: 3.01s
# 14:	learn: 0.2323714	test: 0.3827017	best: 0.3702620 (9)	total: 22.7ms	remaining: 3.01s
# 15:	learn: 0.2228155	test: 0.3707879	best: 0.3702620 (9)	total: 24.3ms	remaining: 3.01s
# 16:	learn: 0.2144538	test: 0.3671614	best: 0.3671614 (16)	total: 25.8ms	remaining: 3.01s
# 17:	learn: 0.2090114	test: 0.3703851	best: 0.3671614 (16)	total: 27.2ms	remaining: 3s
# 18:	learn: 0.2018083	test: 0.3743339	best: 0.3671614 (16)	total: 28.8ms	remaining: 3s
# 19:	learn: 0.1932722	test: 0.3669948	best: 0.3669948 (19)	total: 30.5ms	remaining: 3.02s
# 20:	learn: 0.1846821	test: 0.3641606	best: 0.3641606 (20)	total: 32.1ms	remaining: 3.03s
# 21:	learn: 0.1765566	test: 0.3593789	best: 0.3593789 (21)	total: 33.8ms	remaining: 3.04s
# 22:	learn: 0.1683431	test: 0.3577449	best: 0.3577449 (22)	total: 35.3ms	remaining: 3.03s
# 23:	learn: 0.1600284	test: 0.3651115	best: 0.3577449 (22)	total: 36.7ms	remaining: 3.02s
# 24:	learn: 0.1516731	test: 0.3548310	best: 0.3548310 (24)	total: 38.3ms	remaining: 3.03s
# 25:	learn: 0.1414507	test: 0.3604617	best: 0.3548310 (24)	total: 39.9ms	remaining: 3.03s
# 26:	learn: 0.1387276	test: 0.3596252	best: 0.3548310 (24)	total: 41.4ms	remaining: 3.02s
# 27:	learn: 0.1311173	test: 0.3385506	best: 0.3385506 (27)	total: 42.9ms	remaining: 3.02s
# 28:	learn: 0.1234955	test: 0.3288195	best: 0.3288195 (28)	total: 44.4ms	remaining: 3.02s
# 29:	learn: 0.1195137	test: 0.3190532	best: 0.3190532 (29)	total: 45.9ms	remaining: 3.02s
# 30:	learn: 0.1170809	test: 0.3182182	best: 0.3182182 (30)	total: 47.4ms	remaining: 3.01s
# 31:	learn: 0.1133841	test: 0.3191503	best: 0.3182182 (30)	total: 48.8ms	remaining: 3s
# 32:	learn: 0.1067497	test: 0.3245907	best: 0.3182182 (30)	total: 50.3ms	remaining: 3s
# 33:	learn: 0.1041695	test: 0.3244825	best: 0.3182182 (30)	total: 51.9ms	remaining: 3s
# 34:	learn: 0.0996562	test: 0.3257345	best: 0.3182182 (30)	total: 53.3ms	remaining: 2.99s
# 35:	learn: 0.0983140	test: 0.3235156	best: 0.3182182 (30)	total: 54.8ms	remaining: 2.99s
# 36:	learn: 0.0966651	test: 0.3215032	best: 0.3182182 (30)	total: 56.4ms	remaining: 2.99s
# 37:	learn: 0.0955689	test: 0.3174978	best: 0.3174978 (37)	total: 57.8ms	remaining: 2.98s
# 38:	learn: 0.0939121	test: 0.3169795	best: 0.3169795 (38)	total: 59.3ms	remaining: 2.98s
# 39:	learn: 0.0915174	test: 0.3170506	best: 0.3169795 (38)	total: 60.8ms	remaining: 2.98s
# 40:	learn: 0.0896732	test: 0.3260011	best: 0.3169795 (38)	total: 62.2ms	remaining: 2.97s
# 41:	learn: 0.0875219	test: 0.3238088	best: 0.3169795 (38)	total: 63.5ms	remaining: 2.96s
# 42:	learn: 0.0832766	test: 0.3205683	best: 0.3169795 (38)	total: 65ms	remaining: 2.96s
# 43:	learn: 0.0819269	test: 0.3186473	best: 0.3169795 (38)	total: 66.4ms	remaining: 2.95s
# 44:	learn: 0.0810690	test: 0.3148402	best: 0.3148402 (44)	total: 67.9ms	remaining: 2.95s
# 45:	learn: 0.0802938	test: 0.3118003	best: 0.3118003 (45)	total: 69.6ms	remaining: 2.96s
# 46:	learn: 0.0791418	test: 0.3090374	best: 0.3090374 (46)	total: 71.3ms	remaining: 2.96s
# 47:	learn: 0.0780814	test: 0.3072874	best: 0.3072874 (47)	total: 73.1ms	remaining: 2.97s
# 48:	learn: 0.0723662	test: 0.3042125	best: 0.3042125 (48)	total: 74.9ms	remaining: 2.98s
# 49:	learn: 0.0695021	test: 0.3060724	best: 0.3042125 (48)	total: 76.4ms	remaining: 2.98s
# 50:	learn: 0.0670181	test: 0.3035409	best: 0.3035409 (50)	total: 78ms	remaining: 2.98s
# 51:	learn: 0.0664737	test: 0.3040981	best: 0.3035409 (50)	total: 79.6ms	remaining: 2.98s
# 52:	learn: 0.0658760	test: 0.3021981	best: 0.3021981 (52)	total: 81.2ms	remaining: 2.98s
# 53:	learn: 0.0632211	test: 0.2991582	best: 0.2991582 (53)	total: 82.9ms	remaining: 2.99s
# 54:	learn: 0.0626808	test: 0.2989626	best: 0.2989626 (54)	total: 84.6ms	remaining: 2.99s
# 55:	learn: 0.0620618	test: 0.2983926	best: 0.2983926 (55)	total: 86.3ms	remaining: 3s
# 56:	learn: 0.0598786	test: 0.2965502	best: 0.2965502 (56)	total: 87.9ms	remaining: 3s
# 57:	learn: 0.0565677	test: 0.3077958	best: 0.2965502 (56)	total: 89.8ms	remaining: 3.01s
# 58:	learn: 0.0551443	test: 0.3098295	best: 0.2965502 (56)	total: 91.6ms	remaining: 3.01s
# 59:	learn: 0.0545751	test: 0.3086167	best: 0.2965502 (56)	total: 93.2ms	remaining: 3.01s
# 60:	learn: 0.0542706	test: 0.3080983	best: 0.2965502 (56)	total: 94.8ms	remaining: 3.01s
# 61:	learn: 0.0540084	test: 0.3074004	best: 0.2965502 (56)	total: 96.4ms	remaining: 3.01s
# 62:	learn: 0.0536487	test: 0.3071897	best: 0.2965502 (56)	total: 98.2ms	remaining: 3.02s
# 63:	learn: 0.0532561	test: 0.3048209	best: 0.2965502 (56)	total: 99.8ms	remaining: 3.02s
# 64:	learn: 0.0525117	test: 0.3047533	best: 0.2965502 (56)	total: 101ms	remaining: 3.02s
# 65:	learn: 0.0521064	test: 0.3046326	best: 0.2965502 (56)	total: 103ms	remaining: 3.02s
# 66:	learn: 0.0518180	test: 0.3044461	best: 0.2965502 (56)	total: 105ms	remaining: 3.02s
# 67:	learn: 0.0511996	test: 0.3040109	best: 0.2965502 (56)	total: 106ms	remaining: 3.02s
# 68:	learn: 0.0487187	test: 0.3096023	best: 0.2965502 (56)	total: 108ms	remaining: 3.02s
# 69:	learn: 0.0484933	test: 0.3095012	best: 0.2965502 (56)	total: 109ms	remaining: 3.02s
# 70:	learn: 0.0479187	test: 0.3085470	best: 0.2965502 (56)	total: 111ms	remaining: 3.02s
# 71:	learn: 0.0471896	test: 0.3055135	best: 0.2965502 (56)	total: 113ms	remaining: 3.02s
# 72:	learn: 0.0466371	test: 0.3104540	best: 0.2965502 (56)	total: 114ms	remaining: 3.02s
# 73:	learn: 0.0450353	test: 0.3124159	best: 0.2965502 (56)	total: 116ms	remaining: 3.02s
# 74:	learn: 0.0447739	test: 0.3124080	best: 0.2965502 (56)	total: 118ms	remaining: 3.02s
# 75:	learn: 0.0443036	test: 0.3123612	best: 0.2965502 (56)	total: 119ms	remaining: 3.01s
# 76:	learn: 0.0439586	test: 0.3141039	best: 0.2965502 (56)	total: 120ms	remaining: 3.01s
# 77:	learn: 0.0437922	test: 0.3141507	best: 0.2965502 (56)	total: 122ms	remaining: 3.01s
# 78:	learn: 0.0435991	test: 0.3139640	best: 0.2965502 (56)	total: 123ms	remaining: 3s
# 79:	learn: 0.0426623	test: 0.3134852	best: 0.2965502 (56)	total: 125ms	remaining: 3s
# 80:	learn: 0.0409264	test: 0.3161684	best: 0.2965502 (56)	total: 126ms	remaining: 3s
# 81:	learn: 0.0407123	test: 0.3141433	best: 0.2965502 (56)	total: 128ms	remaining: 2.99s
# 82:	learn: 0.0397061	test: 0.3144632	best: 0.2965502 (56)	total: 130ms	remaining: 2.99s
# 83:	learn: 0.0395171	test: 0.3129925	best: 0.2965502 (56)	total: 131ms	remaining: 2.99s
# 84:	learn: 0.0393801	test: 0.3128667	best: 0.2965502 (56)	total: 133ms	remaining: 2.99s
# 85:	learn: 0.0392157	test: 0.3128723	best: 0.2965502 (56)	total: 134ms	remaining: 2.98s
# 86:	learn: 0.0383197	test: 0.3123175	best: 0.2965502 (56)	total: 136ms	remaining: 2.98s
# 87:	learn: 0.0381766	test: 0.3123774	best: 0.2965502 (56)	total: 137ms	remaining: 2.98s
# 88:	learn: 0.0380315	test: 0.3124653	best: 0.2965502 (56)	total: 139ms	remaining: 2.98s
# 89:	learn: 0.0363238	test: 0.3202353	best: 0.2965502 (56)	total: 140ms	remaining: 2.97s
# 90:	learn: 0.0361869	test: 0.3200036	best: 0.2965502 (56)	total: 142ms	remaining: 2.97s
# 91:	learn: 0.0355365	test: 0.3232242	best: 0.2965502 (56)	total: 143ms	remaining: 2.97s
# 92:	learn: 0.0354267	test: 0.3227580	best: 0.2965502 (56)	total: 145ms	remaining: 2.96s
# 93:	learn: 0.0344895	test: 0.3222100	best: 0.2965502 (56)	total: 146ms	remaining: 2.97s
# 94:	learn: 0.0340493	test: 0.3169431	best: 0.2965502 (56)	total: 148ms	remaining: 2.97s
# 95:	learn: 0.0326630	test: 0.3237110	best: 0.2965502 (56)	total: 150ms	remaining: 2.97s
# 96:	learn: 0.0324970	test: 0.3232770	best: 0.2965502 (56)	total: 151ms	remaining: 2.97s
# 97:	learn: 0.0323457	test: 0.3233151	best: 0.2965502 (56)	total: 153ms	remaining: 2.97s
# 98:	learn: 0.0318519	test: 0.3229338	best: 0.2965502 (56)	total: 154ms	remaining: 2.96s
# 99:	learn: 0.0315415	test: 0.3226387	best: 0.2965502 (56)	total: 156ms	remaining: 2.96s
# 100:	learn: 0.0314194	test: 0.3223939	best: 0.2965502 (56)	total: 157ms	remaining: 2.96s
# 101:	learn: 0.0308131	test: 0.3216536	best: 0.2965502 (56)	total: 159ms	remaining: 2.96s
# 102:	learn: 0.0306986	test: 0.3214136	best: 0.2965502 (56)	total: 160ms	remaining: 2.95s
# 103:	learn: 0.0305406	test: 0.3200319	best: 0.2965502 (56)	total: 162ms	remaining: 2.96s
# 104:	learn: 0.0301534	test: 0.3205665	best: 0.2965502 (56)	total: 164ms	remaining: 2.96s
# 105:	learn: 0.0300112	test: 0.3207038	best: 0.2965502 (56)	total: 165ms	remaining: 2.95s
# 106:	learn: 0.0295142	test: 0.3207694	best: 0.2965502 (56)	total: 167ms	remaining: 2.95s
# 107:	learn: 0.0293145	test: 0.3202145	best: 0.2965502 (56)	total: 168ms	remaining: 2.95s
# 108:	learn: 0.0291955	test: 0.3208292	best: 0.2965502 (56)	total: 170ms	remaining: 2.95s
# 109:	learn: 0.0284447	test: 0.3190352	best: 0.2965502 (56)	total: 171ms	remaining: 2.94s
# 110:	learn: 0.0283457	test: 0.3189291	best: 0.2965502 (56)	total: 173ms	remaining: 2.94s
# 111:	learn: 0.0276775	test: 0.3205858	best: 0.2965502 (56)	total: 174ms	remaining: 2.94s
# 112:	learn: 0.0273628	test: 0.3200283	best: 0.2965502 (56)	total: 176ms	remaining: 2.94s
# 113:	learn: 0.0272457	test: 0.3209390	best: 0.2965502 (56)	total: 178ms	remaining: 2.94s
# 114:	learn: 0.0256330	test: 0.3317469	best: 0.2965502 (56)	total: 179ms	remaining: 2.94s
# 115:	learn: 0.0255612	test: 0.3316325	best: 0.2965502 (56)	total: 181ms	remaining: 2.94s
# 116:	learn: 0.0253569	test: 0.3298671	best: 0.2965502 (56)	total: 182ms	remaining: 2.94s
# 117:	learn: 0.0252450	test: 0.3296411	best: 0.2965502 (56)	total: 184ms	remaining: 2.94s
# 118:	learn: 0.0248955	test: 0.3290974	best: 0.2965502 (56)	total: 186ms	remaining: 2.94s
# 119:	learn: 0.0248092	test: 0.3288399	best: 0.2965502 (56)	total: 187ms	remaining: 2.94s
# 120:	learn: 0.0244314	test: 0.3297704	best: 0.2965502 (56)	total: 189ms	remaining: 2.94s
# 121:	learn: 0.0243368	test: 0.3299208	best: 0.2965502 (56)	total: 191ms	remaining: 2.94s
# 122:	learn: 0.0239744	test: 0.3292789	best: 0.2965502 (56)	total: 192ms	remaining: 2.93s
# 123:	learn: 0.0238362	test: 0.3296557	best: 0.2965502 (56)	total: 194ms	remaining: 2.93s
# 124:	learn: 0.0235410	test: 0.3296501	best: 0.2965502 (56)	total: 195ms	remaining: 2.93s
# 125:	learn: 0.0233414	test: 0.3293588	best: 0.2965502 (56)	total: 197ms	remaining: 2.93s
# 126:	learn: 0.0232616	test: 0.3294181	best: 0.2965502 (56)	total: 198ms	remaining: 2.93s
# 127:	learn: 0.0231672	test: 0.3280981	best: 0.2965502 (56)	total: 200ms	remaining: 2.92s
# 128:	learn: 0.0226171	test: 0.3224304	best: 0.2965502 (56)	total: 202ms	remaining: 2.92s
# 129:	learn: 0.0223064	test: 0.3192880	best: 0.2965502 (56)	total: 203ms	remaining: 2.92s
# 130:	learn: 0.0218451	test: 0.3195896	best: 0.2965502 (56)	total: 205ms	remaining: 2.92s
# 131:	learn: 0.0217310	test: 0.3198774	best: 0.2965502 (56)	total: 206ms	remaining: 2.92s
# 132:	learn: 0.0210960	test: 0.3217773	best: 0.2965502 (56)	total: 208ms	remaining: 2.92s
# 133:	learn: 0.0209882	test: 0.3223613	best: 0.2965502 (56)	total: 209ms	remaining: 2.91s
# 134:	learn: 0.0205597	test: 0.3222527	best: 0.2965502 (56)	total: 211ms	remaining: 2.91s
# 135:	learn: 0.0204720	test: 0.3225582	best: 0.2965502 (56)	total: 212ms	remaining: 2.91s
# 136:	learn: 0.0201308	test: 0.3267056	best: 0.2965502 (56)	total: 214ms	remaining: 2.9s
# 137:	learn: 0.0200778	test: 0.3268031	best: 0.2965502 (56)	total: 215ms	remaining: 2.9s
# 138:	learn: 0.0199907	test: 0.3265717	best: 0.2965502 (56)	total: 217ms	remaining: 2.9s
# 139:	learn: 0.0199488	test: 0.3266188	best: 0.2965502 (56)	total: 218ms	remaining: 2.9s
# 140:	learn: 0.0198389	test: 0.3288564	best: 0.2965502 (56)	total: 220ms	remaining: 2.9s
# 141:	learn: 0.0193426	test: 0.3304968	best: 0.2965502 (56)	total: 221ms	remaining: 2.9s
# 142:	learn: 0.0190851	test: 0.3289834	best: 0.2965502 (56)	total: 223ms	remaining: 2.89s
# 143:	learn: 0.0190465	test: 0.3289171	best: 0.2965502 (56)	total: 225ms	remaining: 2.9s
# 144:	learn: 0.0189968	test: 0.3292483	best: 0.2965502 (56)	total: 226ms	remaining: 2.89s
# 145:	learn: 0.0189515	test: 0.3290529	best: 0.2965502 (56)	total: 228ms	remaining: 2.89s
# 146:	learn: 0.0184503	test: 0.3336253	best: 0.2965502 (56)	total: 229ms	remaining: 2.89s
# 147:	learn: 0.0183926	test: 0.3335165	best: 0.2965502 (56)	total: 230ms	remaining: 2.88s
# 148:	learn: 0.0183264	test: 0.3331900	best: 0.2965502 (56)	total: 232ms	remaining: 2.88s
# 149:	learn: 0.0182622	test: 0.3333985	best: 0.2965502 (56)	total: 233ms	remaining: 2.88s
# 150:	learn: 0.0181892	test: 0.3332328	best: 0.2965502 (56)	total: 235ms	remaining: 2.88s
# 151:	learn: 0.0180457	test: 0.3297318	best: 0.2965502 (56)	total: 237ms	remaining: 2.88s
# 152:	learn: 0.0179863	test: 0.3295674	best: 0.2965502 (56)	total: 238ms	remaining: 2.87s
# 153:	learn: 0.0177675	test: 0.3328831	best: 0.2965502 (56)	total: 240ms	remaining: 2.87s
# 154:	learn: 0.0177055	test: 0.3332681	best: 0.2965502 (56)	total: 241ms	remaining: 2.87s
# 155:	learn: 0.0176535	test: 0.3334621	best: 0.2965502 (56)	total: 243ms	remaining: 2.87s
# 156:	learn: 0.0176072	test: 0.3333564	best: 0.2965502 (56)	total: 244ms	remaining: 2.87s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2965501572
# bestIteration = 56
#
# Shrink model to first 57 iterations.
# [0.9217391304347826, 0.8817204301075269, 0.9176470588235294, 0.8717948717948718, 0.9263157894736843]
